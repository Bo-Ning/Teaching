# %% [markdown]
# # Lecture 9
#
# Feburary 03, 2022
#
# ### Announcements
#
# * HW 3 due next week
# * HW 1 grade available this Friday
#
# ### Topics
#
# * Web Scraping
#
# ### Datasets
#
# * [CUESA's Vegetable Seasons Chart](https://cuesa.org/eat-seasonally/charts/vegetables)
# * [Craigslist Apartments](https://sacramento.craigslist.org/d/apts-housing-for-rent/search/apa)
#
# ### References
#
# * [__requests__ documentation](http://docs.python-requests.org/en/master/)
# * [__requests-html__ documentation](https://html.python-requests.org/)
# * [MDN HTML Reference](https://developer.mozilla.org/en-US/docs/Web/HTML/Element)
# * [XPath Diner](http://www.topswagcode.com/xpath/) -- an interactive XPath tutorial
# * [CSS Diner](https://flukeout.github.io/) -- an interactive CSS Selector tutorial
# * Python for Data Analysis, Ch. 6
# * Python for Data Analysis, Ch. 7.3 (to review string processing)
#
# [PDSH]: https://jakevdp.github.io/PythonDataScienceHandbook/
# [ProGit]: https://git-scm.com/book/

# %% [markdown]
# ## A remark on `<span>`
#
#
# The `<span>` tag is an inline container used to mark up a part of a text, or a part of a document.
#
# For example, you can write the code
# ```
# <p>My hat is <span style="color:blue">blue</span>.</p>
# ```
#
# <p>My hat is <span style="color:blue">blue</span>.</p>

# %% [markdown]
# ## A remark on XML

# %% [markdown]
# In the last lecture, we discussed HTML and XML.
#
# __XML__ (Extensible Markup Language) is a markup language similar to _HTML_, but without predefined tags to use. Instead, you define your own tags designed specifically for your needs.
#
# What is markup language?
#
# Markup is information added to a document that enhances its meaning in certain ways, in that it identifies the parts and how they relate to each other. More specifically, a markup language is a set of symbols that can be placed in the text of a document to demarcate and label the parts of that document. [Reference](https://www.tutorialspoint.com/xml/xml_overview.htm)
#
#
# In many HTML applications, XML is used to store or transport data, while HTML is used to format and display the same data.
#
# XML online editor can be found [here](https://jsonformatter.org/xml-editor)

# %% [markdown]
# For example,
# ```
# <message>
#    <text>Hello, world!</text>
# </message>
# ```
#
# This snippet includes the markup symbols, or the tags such as `<message>...</message>` and `<text>... </text>`. The tags `<message>` and `</message>` mark the start and the end of the XML code fragment. The tags `<text>` and `</text>` surround the text Hello, world!.

# %% [markdown]
# Another example:
#
# ```
# <?xml version = "1.0" encoding = "UTF-8"?>
# <contact-info>
#    <name>Tanmay Patil</name>
#    <company>TutorialsPoint</company>
#    <phone>(011) 123-4567</phone>
# </contact-info>
# ```
#
# * XML Declaration: `<?xml version = "1.0" encoding = "UTF-8"?>`
#
# This part is optional, if document contains XML declaration, then it strictly needs to be the first statement of the XML document.
#
# * Element Syntax: Each XML-element needs to be closed either with start or with end elements OR simply `<contact-info/>`
#
# * Nesting of Elements: XML can have multiple nested elements, e.g., name, company, phone
#
# * The names of XML-elements are case-sensitive!
#
# * Each XML document has exactly one single root element. It encloses all the other elements and is therefore the sole parent element to all the other elements. In this example, i.e., contact-info
#
# Sample XML examples: [here](https://docs.oracle.com/cd/E19857-01/819-6518/abxii/index.html)

# %% [markdown]
# ## Writing Scrapers
#
# In the last lecture, we did web scraping from wikipedia.

# %% [markdown]
# The `read_html` function searches for `<table>` elements and only for `<tr>` and `<th>` rows and `<td>` elements within each `<tr>` or `<th>` element in the table. `<td>` stands for “table data”.
#
# Let's inspect the Wikipedia list of [US cities by area][wiki].
#
# [wiki]: https://en.wikipedia.org/wiki/List_of_United_States_cities_by_area

# %% [markdown]
# When the data we want isn't in a `table` element or request was forbidden, we have to write our own scraper.
#
# The workflow for writing a scraper is the same regardless of the language you use:
#
# 1. Download pages with an HTTP request (usually `GET`)
# 2. Parse pages to extract text
# 3. Clean up extracted text with string methods or regex
# 4. Save cleaned results

# %% [markdown]
# ### Example: CUESA Vegetable Seasons
#
#
#
# CUESA (Center for Urban Education about Sustainable Agriculture) provides [a chart](https://cuesa.org/eat-seasonally/charts/vegetables) that shows when vegetables are in season. Let's scrape the chart.

# %%
import pandas as pd
result = pd.read_html("https://cuesa.org/eat-seasonally/charts/vegetables")

# does not work
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-12-95e90f13089b> in <module>
#       1 import pandas as pd
# ----> 2 result = pd.read_html("https://cuesa.org/eat-seasonally/charts/vegetables")
#       3
#       4 # does not work
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     297                 )
#     298                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299             return func(*args, **kwargs)
#     300
#     301         return wrapper
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1083     io = stringify_path(io)
#    1084
# -> 1085     return _parse(
#    1086         flavor=flavor,
#    1087         io=io,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     891
#     892         try:
# --> 893             tables = p.parse_tables()
#     894         except ValueError as caught:
#     895             # if `io` is an io-like object, check if it's seekable
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/html.py in parse_tables(self)
#     211         list of parsed (header, body, footer) tuples from tables.
#     212         """
# --> 213         tables = self._parse_tables(self._build_doc(), self.match, self.attrs)
#     214         return (self._parse_thead_tbody_tfoot(table) for table in tables)
#     215
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/html.py in _build_doc(self)
#     730                     pass
#     731             else:
# --> 732                 raise e
#     733         else:
#     734             if not hasattr(r, "text_content"):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/html.py in _build_doc(self)
#     711         try:
#     712             if is_url(self.io):
# --> 713                 with urlopen(self.io) as f:
#     714                     r = parse(f, parser=parser)
#     715             else:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/common.py in urlopen(*args, **kwargs)
#     193     import urllib.request
#     194
# --> 195     return urllib.request.urlopen(*args, **kwargs)
#     196
#     197
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in http_response(self, request, response)
#     638         # request was successfully received, understood, and accepted.
#     639         if not (200 <= code < 300):
# --> 640             response = self.parent.error(
#     641                 'http', request, response, code, msg, hdrs)
#     642
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in error(self, proto, *args)
#     567         if http_err:
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#     571 # XXX probably also want an abstract factory that knows when it makes
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     647 class HTTPDefaultErrorHandler(BaseHandler):
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#     651 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 403: Forbidden

# %%
import requests
import lxml.html as lx

# there is no import lxml.xml
# lxml: processing XML and HTML with Python

# %%
# Download the page
response = requests.get("https://cuesa.org/eat-seasonally/charts/vegetables")

# %%
response.raise_for_status
# Out:
# <bound method Response.raise_for_status of <Response [200]>>

# %%
# Parse the HTML
html = lx.fromstring(response.text)
html
# Out:
# <Element html at 0x7f81ea3c3130>

# %%
# Find the table with the vegetable seasons
tab = html.xpath("//table")[0]
tab
# Out:
# <Element table at 0x7f81ea3cbae0>

# %%
rows = tab.xpath(".//tr")
rows = rows[1:]
rows
# Out:
# [<Element tr at 0x7f81ea3cb950>,
#  <Element tr at 0x7f81ea3cbc70>,
#  <Element tr at 0x7f81ea3cb770>,
#  <Element tr at 0x7f81ea3cbd10>,
#  <Element tr at 0x7f81ea3cb860>,
#  <Element tr at 0x7f81ea3cb8b0>,
#  <Element tr at 0x7f81ea3cb9a0>,
#  <Element tr at 0x7f81ea3cbdb0>,
#  <Element tr at 0x7f81ea3cbe00>,
#  <Element tr at 0x7f81ea3cbe50>,
#  <Element tr at 0x7f81ea3cbea0>,
#  <Element tr at 0x7f81ea3cbef0>,
#  <Element tr at 0x7f81ea3cbf40>,
#  <Element tr at 0x7f81ea3cbf90>,
#  <Element tr at 0x7f81ea3d2040>,
#  <Element tr at 0x7f81ea3d2090>,
#  <Element tr at 0x7f81ea3d20e0>,
#  <Element tr at 0x7f81ea3d2130>,
#  <Element tr at 0x7f81ea3d2180>,
#  <Element tr at 0x7f81ea3d21d0>,
#  <Element tr at 0x7f81ea3d2220>,
#  <Element tr at 0x7f81ea3d2270>,
#  <Element tr at 0x7f81ea3d22c0>,
#  <Element tr at 0x7f81ea3d2310>,
#  <Element tr at 0x7f81ea3d2360>,
#  <Element tr at 0x7f81ea3d23b0>,
#  <Element tr at 0x7f81ea3d2400>,
#  <Element tr at 0x7f81ea3d2450>,
#  <Element tr at 0x7f81ea3d24a0>,
#  <Element tr at 0x7f81ea3d24f0>,
#  <Element tr at 0x7f81ea3d2540>,
#  <Element tr at 0x7f81ea3d2590>,
#  <Element tr at 0x7f81ea3d25e0>,
#  <Element tr at 0x7f81ea3d2630>,
#  <Element tr at 0x7f81ea3d2680>,
#  <Element tr at 0x7f81ea3d26d0>,
#  <Element tr at 0x7f81ea3d2720>,
#  <Element tr at 0x7f81ea3d2770>,
#  <Element tr at 0x7f81ea3d27c0>,
#  <Element tr at 0x7f81ea3d2810>,
#  <Element tr at 0x7f81ea3d2860>,
#  <Element tr at 0x7f81ea3d28b0>,
#  <Element tr at 0x7f81ea3d2900>,
#  <Element tr at 0x7f81ea3d2950>,
#  <Element tr at 0x7f81ea3d29a0>,
#  <Element tr at 0x7f81ea3d29f0>,
#  <Element tr at 0x7f81ea3d2a40>,
#  <Element tr at 0x7f81ea3d2a90>,
#  <Element tr at 0x7f81ea3d2ae0>,
#  <Element tr at 0x7f81ea3d2b30>,
#  <Element tr at 0x7f81ea3d2b80>,
#  <Element tr at 0x7f81ea3d2bd0>,
#  <Element tr at 0x7f81ea3d2c20>,
#  <Element tr at 0x7f81ea3d2c70>,
#  <Element tr at 0x7f81ea3d2cc0>,
#  <Element tr at 0x7f81ea3d2d10>,
#  <Element tr at 0x7f81ea3d2d60>,
#  <Element tr at 0x7f81ea3d2db0>,
#  <Element tr at 0x7f81ea3d2e00>,
#  <Element tr at 0x7f81ea3d2e50>,
#  <Element tr at 0x7f81ea3d2ea0>,
#  <Element tr at 0x7f81ea3d2ef0>,
#  <Element tr at 0x7f81ea3d2f40>,
#  <Element tr at 0x7f81ea3d2f90>,
#  <Element tr at 0x7f81ea3d1040>,
#  <Element tr at 0x7f81ea3d1090>,
#  <Element tr at 0x7f81ea3d10e0>,
#  <Element tr at 0x7f81ea3d1130>,
#  <Element tr at 0x7f81ea3d1180>,
#  <Element tr at 0x7f81ea3d11d0>,
#  <Element tr at 0x7f81ea3d1220>]

# %%
# Extract the header
header = rows[0]
header = [x.text for x in header.xpath(".//li")]
header
# Out:
# ['Jan',
#  'Feb',
#  'Mar',
#  'Apr',
#  'May',
#  'June',
#  'July',
#  'Aug',
#  'Sept',
#  'Oct',
#  'Nov',
#  'Dec']

# %% [markdown]
# Now, we want to print out the vegetable name and its url.
# Eventually, we want to create a function to get the table for vegetables.

# %%
base_url = "https://cuesa.org/eat-seasonally/charts/vegetables"
response = requests.get(base_url)
response.raise_for_status()

# %%
# Parse the HTML
html = lx.fromstring(response.text)
html.make_links_absolute(base_url)
html
# Out:
# <Element html at 0x7f81ec77ed10>

# %%
# Find the table with the vegetable seasons
tab = html.xpath("//table")
print(tab)
tab = tab[0]
tab
# Out:
# [<Element table at 0x7f81ec77eb30>]
# <Element table at 0x7f81ec77eb30>

# %%
h, b = tab.getchildren()
print(h)
print(b)
# Out:
# <Element thead at 0x7f81ec754900>
# <Element tbody at 0x7f81ec7549a0>

# %%
# Extract the header
food = base_url.rsplit("/", 1)[-1]
food
# Out:
# 'vegetables'

# %%
# Extract the header
header = [food, "url"] + [x.text for x in h.xpath(".//li")] # adding food and url together
header # now the header looks good
# Out:
# ['vegetables',
#  'url',
#  'Jan',
#  'Feb',
#  'Mar',
#  'Apr',
#  'May',
#  'June',
#  'July',
#  'Aug',
#  'Sept',
#  'Oct',
#  'Nov',
#  'Dec']

# %%
rows = b.xpath(".//tr") # we going to get the rows
rows
# Out:
# [<Element tr at 0x7f81ec713f40>,
#  <Element tr at 0x7f81ec713cc0>,
#  <Element tr at 0x7f81ec7180e0>,
#  <Element tr at 0x7f81ea3c30e0>,
#  <Element tr at 0x7f81ec726c70>,
#  <Element tr at 0x7f81ec726bd0>,
#  <Element tr at 0x7f81ec726b80>,
#  <Element tr at 0x7f81ec71c6d0>,
#  <Element tr at 0x7f81ea3d1e50>,
#  <Element tr at 0x7f81ec77eb80>,
#  <Element tr at 0x7f81ec77e4f0>,
#  <Element tr at 0x7f81ec77e950>,
#  <Element tr at 0x7f81ec77e0e0>,
#  <Element tr at 0x7f81ec77e400>,
#  <Element tr at 0x7f81ec77e450>,
#  <Element tr at 0x7f81ec77e630>,
#  <Element tr at 0x7f81ec77e810>,
#  <Element tr at 0x7f81ec77e860>,
#  <Element tr at 0x7f81ec77e090>,
#  <Element tr at 0x7f81ec6fb1d0>,
#  <Element tr at 0x7f81ec6fbae0>,
#  <Element tr at 0x7f81ec6fb950>,
#  <Element tr at 0x7f81ec6fb680>,
#  <Element tr at 0x7f81ec7720e0>,
#  <Element tr at 0x7f81ec772130>,
#  <Element tr at 0x7f81ec772c20>,
#  <Element tr at 0x7f81ec772f40>,
#  <Element tr at 0x7f81ec7723b0>,
#  <Element tr at 0x7f81ec772220>,
#  <Element tr at 0x7f81ec772b80>,
#  <Element tr at 0x7f81ec7a3220>,
#  <Element tr at 0x7f81ec7a3860>,
#  <Element tr at 0x7f81ec7a39f0>,
#  <Element tr at 0x7f81ec7a35e0>,
#  <Element tr at 0x7f81ec7a3950>,
#  <Element tr at 0x7f81ec7a39a0>,
#  <Element tr at 0x7f81ec7a3db0>,
#  <Element tr at 0x7f81ec7a3770>,
#  <Element tr at 0x7f81ec7a3f40>,
#  <Element tr at 0x7f81ec7a3b80>,
#  <Element tr at 0x7f81ec7a34a0>,
#  <Element tr at 0x7f81ec7a3a90>,
#  <Element tr at 0x7f81ec7a3310>,
#  <Element tr at 0x7f81ec7a3720>,
#  <Element tr at 0x7f81ec7a34f0>,
#  <Element tr at 0x7f81ec7a3ef0>,
#  <Element tr at 0x7f81ec7a3d60>,
#  <Element tr at 0x7f81ec7a3450>,
#  <Element tr at 0x7f81ec7a3590>,
#  <Element tr at 0x7f81ec7a3ea0>,
#  <Element tr at 0x7f81ec7a3e50>,
#  <Element tr at 0x7f81ec7a3ae0>,
#  <Element tr at 0x7f81ec7a32c0>,
#  <Element tr at 0x7f81ec7a3d10>,
#  <Element tr at 0x7f81ec7a3680>,
#  <Element tr at 0x7f81ec7a3630>,
#  <Element tr at 0x7f81ec7a36d0>,
#  <Element tr at 0x7f81ec7a3540>,
#  <Element tr at 0x7f81ec7a3cc0>,
#  <Element tr at 0x7f81ec7a3a40>,
#  <Element tr at 0x7f81ec7a3b30>,
#  <Element tr at 0x7f81ec7a3810>,
#  <Element tr at 0x7f81ec7a3360>,
#  <Element tr at 0x7f81ec79d450>,
#  <Element tr at 0x7f81ec79d360>,
#  <Element tr at 0x7f81ec79d4f0>,
#  <Element tr at 0x7f81ec79d5e0>,
#  <Element tr at 0x7f81ec7abd60>,
#  <Element tr at 0x7f81ec7abe50>,
#  <Element tr at 0x7f81ec7abea0>]

# %%
row = rows[0]
link = row.xpath(".//a")[0]
name = link.text_content()
# One way to get href:
url = link.xpath("@href")[0]
url
# Use .get() to get a default value if the attribute doesn't exist.
#link.attrib.get("style", "")

# Get li tags for this row
seasons = row.xpath(".//li/@class")

# %%
row = rows[0]
link = row.xpath(".//a")[0]
link
# Out:
# <Element a at 0x7f81ec77da90>

# %%
name = link.text_content() # name of the link
name
# Out:
# 'Artichokes'

# %%
# One way to get href:
url = link.xpath("@href")[0]
url
# Out:
# 'https://cuesa.org/food/artichokes'

# %%
# Get li tags for this row
seasons = row.xpath(".//li/@class")
seasons
# Out:
# ['month',
#  'month',
#  'month season',
#  'month season',
#  'month season',
#  'month season',
#  'month',
#  'month',
#  'month season',
#  'month season',
#  'month season',
#  'month season']

# %%
tab_line = [name, url] + ["season" in x or "market" in x for x in seasons]
tab_line
# Out:
# ['Artichokes',
#  'https://cuesa.org/food/artichokes',
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True]

# %% [markdown]
# Now we want to do this for all rows:

# %%
def extract_row(row):
    # We started looking at one row here:
    #row = rows[0]

    link = row.xpath(".//a")[0]
    name = link.text_content()
    # One way to get href:
    url = link.xpath("@href")[0]
    url
    # Use .get() to get a default value if the attribute doesn't exist.
    #link.attrib.get("style", "")

    # Get li tags for this row
    seasons = row.xpath(".//li/@class")
    return [name, url] + ["season" in x or "market" in x for x in seasons] # season
    #pd.Series(seasons).str.contains("season")

def scrape_cuesa_chart(base_url, food = None):
    # Download the page
    #base_url = "https://cuesa.org/eat-seasonally/charts/vegetables"
    if food is None:
        food = base_url.rsplit("/", 1)[-1]
    
    response = requests.get(base_url)
    response.raise_for_status()

    # Parse the HTML
    html = lx.fromstring(response.text)
    html.make_links_absolute(base_url)
    html

    # Find the table with the vegetable seasons
    tab = html.xpath("//table")
    print(tab)
    tab = tab[0]

    h, b = tab.getchildren()

    # Extract the header
    header = [food, "url"] + [x.text for x in h.xpath(".//li")]

    rows = b.xpath(".//tr")

    return pd.DataFrame([extract_row(row) for row in rows], columns = header)

scrape_cuesa_chart("https://cuesa.org/eat-seasonally/charts/vegetables")
# Out:
# [<Element table at 0x7f81ea3f6400>]
#       vegetables                                  url    Jan    Feb    Mar  \
# 0     Artichokes    https://cuesa.org/food/artichokes  False  False   True
# 1        Arugula       https://cuesa.org/food/arugula   True   True   True
# 2      Asparagus     https://cuesa.org/food/asparagus  False   True   True
# 3          Beets         https://cuesa.org/food/beets   True   True   True
# 4   Bitter melon  https://cuesa.org/food/bitter-melon  False  False  False
# ..           ...                                  ...    ...    ...    ...
# 65        Tatsoi        https://cuesa.org/food/tatsoi   True   True   True
# 66    Tomatillos    https://cuesa.org/food/tomatillos  False  False  False
# 67      Tomatoes      https://cuesa.org/food/tomatoes  False  False  False
# 68       Turnips       https://cuesa.org/food/turnips   True   True   True
# 69         Yacon         https://cuesa.org/food/yacon  False  False  False
#
#       Apr    May   June   July    Aug   Sept    Oct    Nov    Dec
# 0    True   True   True  False  False   True   True   True   True
# 1    True   True   True   True   True   True   True   True   True
# 2    True   True   True  False  False  False  False  False  False
# 3    True   True   True   True   True   True   True   True   True
# 4   False  False   True   True   True   True   True   True  False
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 65   True  False  False  False  False  False   True   True   True
# 66  False  False   True   True   True   True   True   True  False
# 67   True   True   True   True   True   True   True   True  False
# 68   True   True   True   True   True   True   True   True   True
# 69  False  False  False  False  False  False  False   True   True
#
# [70 rows x 14 columns]

# %%
# Check if "season" or "market" is in "month market"
"season" in "month market" or "market" in "month market"
# Out:
# True

# %%
"season" in "month market"
# Out:
# False

# %% [markdown]
# Can we generalize our scraper to the [chart](https://cuesa.org/eat-seasonally/charts/fruit) for fruit and nuts?

# %%
scrape_cuesa_chart("https://cuesa.org/eat-seasonally/charts/fruit", "fruit")
# Out:
# [<Element table at 0x7f81ea3d5e50>]
#             fruit                                   url    Jan    Feb    Mar  \
# 0         Almonds        https://cuesa.org/food/almonds   True   True   True
# 1          Apples         https://cuesa.org/food/apples   True   True   True
# 2        Apricots       https://cuesa.org/food/apricots  False  False  False
# 3         Apriums        https://cuesa.org/food/apriums  False  False  False
# 4     Asian pears    https://cuesa.org/food/asian-pears   True   True   True
# 5        Avocados       https://cuesa.org/food/avocados  False   True   True
# 6    Blackberries   https://cuesa.org/food/blackberries  False  False  False
# 7     Blueberries    https://cuesa.org/food/blueberries  False  False  False
# 8   Boysenberries  https://cuesa.org/food/boysenberries  False  False  False
# 9    Cactus pears   https://cuesa.org/food/cactus-pears  False  False  False
# 10     Cherimoyas     https://cuesa.org/food/cherimoyas   True   True   True
# 11       Cherries       https://cuesa.org/food/cherries  False  False  False
# 12      Chestnuts      https://cuesa.org/food/chestnuts  False  False  False
# 13         Citron         https://cuesa.org/food/citron   True  False  False
# 14          Dates          https://cuesa.org/food/dates   True   True   True
# 15        Feijoas        https://cuesa.org/food/feijoas  False  False  False
# 16           Figs           https://cuesa.org/food/figs  False  False  False
# 17     Grapefruit     https://cuesa.org/food/grapefruit   True   True   True
# 18         Grapes         https://cuesa.org/food/grapes  False  False  False
# 19         Guavas         https://cuesa.org/food/guavas  False   True   True
# 20        Jujubes        https://cuesa.org/food/jujubes  False  False  False
# 21           Kiwi           https://cuesa.org/food/kiwi   True   True   True
# 22       Kumquats       https://cuesa.org/food/kumquats   True   True   True
# 23         Lemons         https://cuesa.org/food/lemons   True   True   True
# 24          Limes          https://cuesa.org/food/limes   True   True   True
# 25   Loganberries   https://cuesa.org/food/loganberries  False  False  False
# 26        Loquats        https://cuesa.org/food/loquats  False  False  False
# 27      Mandarins      https://cuesa.org/food/mandarins   True   True   True
# 28         Melons         https://cuesa.org/food/melons  False  False  False
# 29     Mulberries     https://cuesa.org/food/mulberries  False  False  False
# 30     Nectarines     https://cuesa.org/food/nectarines  False  False  False
# 31         Olives         https://cuesa.org/food/olives   True  False  False
# 32        Oranges        https://cuesa.org/food/oranges   True   True   True
# 33        Peaches        https://cuesa.org/food/peaches  False  False  False
# 34      Peacotums      https://cuesa.org/food/peacotums  False  False  False
# 35        Peanuts        https://cuesa.org/food/peanuts  False  False  False
# 36          Pears          https://cuesa.org/food/pears   True   True   True
# 37         Pecans         https://cuesa.org/food/pecans   True   True   True
# 38     Persimmons     https://cuesa.org/food/persimmons   True   True   True
# 39     Pistachios     https://cuesa.org/food/pistachios   True   True   True
# 40          Plums          https://cuesa.org/food/plums  False  False  False
# 41         Pluots         https://cuesa.org/food/pluots  False  False  False
# 42   Pomegranates   https://cuesa.org/food/pomegranates  False  False  False
# 43        Pomelos        https://cuesa.org/food/pomelos   True   True   True
# 44         Quince         https://cuesa.org/food/quince  False  False  False
# 45    Raspberries    https://cuesa.org/food/raspberries  False  False  False
# 46        Rhubarb        https://cuesa.org/food/rhubarb  False  False  False
# 47   Strawberries   https://cuesa.org/food/strawberries  False  False   True
# 48     Tayberries     https://cuesa.org/food/tayberries  False  False  False
# 49        Walnuts        https://cuesa.org/food/walnuts   True   True   True
#
#       Apr    May   June   July    Aug   Sept    Oct    Nov    Dec
# 0    True   True   True   True   True   True   True   True   True
# 1    True   True   True   True   True   True   True   True   True
# 2   False   True   True   True  False  False  False  False  False
# 3   False   True   True  False  False  False  False  False  False
# 4    True  False  False  False  False   True   True   True   True
# 5    True   True   True   True   True   True   True   True   True
# 6   False   True   True   True   True   True   True  False  False
# 7   False   True   True   True   True  False  False  False  False
# 8   False  False   True   True  False  False  False  False  False
# 9   False   True   True   True   True   True   True   True  False
# 10   True   True  False  False  False  False  False   True   True
# 11   True   True   True   True  False  False  False  False  False
# 12  False  False  False  False  False   True   True   True   True
# 13  False  False  False  False  False  False  False   True   True
# 14   True   True   True   True   True   True   True   True   True
# 15  False  False  False  False  False  False  False   True   True
# 16  False  False   True   True  False   True   True  False  False
# 17   True  False  False  False  False  False  False  False   True
# 18  False  False  False   True   True   True   True   True  False
# 19   True  False  False  False  False  False  False  False  False
# 20  False  False  False  False  False   True   True  False  False
# 21  False  False  False  False  False   True   True   True   True
# 22   True  False  False  False  False  False  False  False  False
# 23   True   True   True   True   True   True   True   True   True
# 24   True  False  False  False  False  False   True   True   True
# 25  False  False   True   True  False  False  False  False  False
# 26  False   True   True  False  False  False  False  False  False
# 27   True   True   True   True  False  False  False   True   True
# 28  False  False   True   True   True   True   True  False  False
# 29  False  False  False   True   True  False  False  False  False
# 30  False   True   True   True   True   True   True  False  False
# 31  False  False  False  False  False   True   True   True   True
# 32   True   True   True   True   True   True   True   True   True
# 33  False   True   True   True   True   True   True  False  False
# 34  False  False  False   True   True  False  False  False  False
# 35  False  False  False   True   True  False  False  False  False
# 36   True  False  False  False   True   True   True   True   True
# 37   True   True   True   True   True   True   True   True   True
# 38  False  False  False  False  False   True   True   True   True
# 39   True   True   True   True   True   True   True   True   True
# 40  False   True   True   True   True   True   True   True  False
# 41  False   True   True   True   True   True  False  False  False
# 42  False  False  False  False  False   True   True   True   True
# 43   True  False  False  False  False  False  False   True   True
# 44  False  False  False  False  False   True   True   True  False
# 45  False   True   True   True   True   True   True   True  False
# 46   True   True   True   True  False  False  False  False  False
# 47   True   True   True   True   True   True   True   True  False
# 48  False  False   True   True   True  False  False  False  False
# 49   True   True   True   True   True   True   True   True   True

# %%
"https://cuesa.org/eat-seasonally/charts/fruit".rsplit("/", 1)[-1]
# Out:
# 'fruit'

# %% [markdown]
# ### Example: Craigslist Apartments
#
# [Craigslist](https://www.craigslist.org/) is a popular website where people can post advertisements for free. We can use data from Craigslist to analyze the local rental market for apartments.
#
# Craigslist doesn't provide an API, so we have to scrape the data ourselves. Scraping Craigslist is the biggest challenge we've faced yet, since each ad is on a separate page.
#
# We can start by scraping the front page of the [apartments section](https://sacramento.craigslist.org/d/apts-housing-for-rent/search/apa) for links to individual ads.

# %%
# Our usual data science tools
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy as sp # other science tools
# statsmodels -- "traditional" statistical models
# scikit-learn -- machine learning models
import seaborn as sns
#from plotnine import *

# %matplotlib inline

# Web scraping tools
import lxml.html as lx
import requests
import requests_cache

requests_cache.install_cache("../craigslist")

# %%
start_url = "https://sacramento.craigslist.org/d/apts-housing-for-rent/search/apa"

def scrape_front_page(url):
    response = requests.get(url)
    response.raise_for_status()
    html = lx.fromstring(response.text)
    html.make_links_absolute(url)

    html

    # Get all <a> tags with class "result-title"
    links = html.xpath("//a[contains(@class, 'result-title')]/@href")
    
    next_page = html.xpath("//a[contains(@class, 'next')]/@href")[0]
    
    return next_page, links

next_page, links = scrape_front_page(start_url)
scrape_front_page(next_page)
# Out:
# ('https://sacramento.craigslist.org/d/apartments-housing-for-rent/search/apa?s=240',
#  ['https://sacramento.craigslist.org/apa/d/sacramento-move-in-special-the-core/7407010198.html',
#   'https://sacramento.craigslist.org/apa/d/great-location-limited-time-only-apply/7407018440.html',
#   'https://sacramento.craigslist.org/apa/d/roseville-bedroom-bathroom-duplex/7405747529.html',
#   'https://sacramento.craigslist.org/apa/d/sacramento-plush-carpet-woodgrain/7407017329.html',
#   'https://sacramento.craigslist.org/apa/d/sacramento-luxurious-bedroom-units/7393782386.html',
#   'https://sacramento.craigslist.org/apa/d/woodland-welcome-to-your-new-home/7407023660.html',
#   'https://sacramento.craigslist.org/apa/d/sacramento-1bd-1ba-home-for-rent/7407021134.html',
#   'https://sacramento.craigslist.org/apa/d/sacramento-1st-floor-studio-with/7406958058.html',
#   'https://sacramento.craigslist.org/apa/d/west-sacramento-microwave-ceiling-fan/7407020161.html',
#   'https://sacramento.craigslist.org/apa/d/antelope-look-and-lease-this-bedroom-is/7407020108.html',
#   'https://sacramento.craigslist.org/apa/d/sacramento-build-your-credit-using/7406100349.html',
#   'https://sacramento.craigslist.org/apa/d/woodland-now-accepting-application/7407019448.html',
#   'https://sacramento.craigslist.org/apa/d/citrus-heights-free-rent-until-december/7407014370.html',
#   'https://sacramento.craigslist.org/apa/d/antelope-so-much-space-bedroom-service/7407013712.html',
#   'https://sacramento.craigslist.org/apa/d/sacramento-incredible-upstairs-two/7407007200.html',
#   'https://sacramento.craigslist.org/apa/d/citrus-heights-upstairs-bd-with-ample/7407018307.html',
#   'https://sacramento.craigslist.org/apa/d/rancho-cordova-stylish-club-house/7403206731.html',
#   'https://sacramento.craigslist.org/apa/d/elk-grove-bd-fireplace-granite-kitchen/7407013245.html',
#   'https://sacramento.craigslist.org/apa/d/west-sacramento-monticello-at-southport/7407017308.html',
#   'https://sacramento.craigslist.org/apa/d/citrus-heights-downstairs-studio-with/7407016281.html',
#   'https://sacramento.craigslist.org/apa/d/sacramento-sunflorin-has-availability/7406994559.html',
#   'https://sacramento.craigslist.org/apa/d/big-beautiful-upgraded-bedroom/7407016065.html',
#   'https://sacramento.craigslist.org/apa/d/hood-bedroom-bath-farm-house-in-elk/7403417731.html',
#   'https://sacramento.craigslist.org/apa/d/sacramento-bedroom-home-in-sacramento/7393605731.html',
#   'https://sacramento.craigslist.org/apa/d/sacramento-updated-bedroom-bath/7400082687.html',
#   'https://sacramento.craigslist.org/apa/d/roseville-spacious-bedroom-west/7403916509.html',
#   'https://sacramento.craigslist.org/apa/d/sacramento-experience-luxury-living-two/7404544099.html',
#   'https://sacramento.craigslist.org/apa/d/elk-grove-8276-crystal-walk-circle/7407014493.html',
#   'https://sacramento.craigslist.org/apa/d/elk-grove-bed-onsite-playground-in-elk/7407011972.html',
#   'https://sacramento.craigslist.org/apa/d/sacramento-up-to-1000-visa-gift-large/7406999038.html',
#   'https://sacramento.craigslist.org/apa/d/sacramento-wonderful-apartment-great/7406990841.html',
#   'https://sacramento.craigslist.org/apa/d/vacaville-bedroom-private-balcony-or/7407001816.html',
#   'https://sacramento.craigslist.org/apa/d/sacramento-for-spectacular-high-rise/7407009755.html',
#   'https://sacramento.craigslist.org/apa/d/woodland-community-pea-patch-dog-park/7403702995.html',
#   'https://sacramento.craigslist.org/apa/d/sacramento-bed-bath-ready-to-view-now/7407008292.html',
#   'https://sacramento.craigslist.org/apa/d/antelope-super-clean-building-remodeled/7406996510.html',
#   'https://sacramento.craigslist.org/apa/d/elk-grove-bd-ba-barbecue-pavilion-and/7407001943.html',
#   'https://sacramento.craigslist.org/apa/d/move-in-ready-today-beautiful-upgraded/7407006579.html',
#   'https://sacramento.craigslist.org/apa/d/sacramento-walk-in-closet-fitness/7395834022.html',
#   'https://sacramento.craigslist.org/apa/d/sacramento-for-the-best-location-in/7407005674.html',
#   'https://sacramento.craigslist.org/apa/d/private-patio-yard-two-bedroom-cottage/7407005151.html',
#   'https://sacramento.craigslist.org/apa/d/fair-oaks-2b-2b-in-home-washer-and/7406076463.html',
#   'https://sacramento.craigslist.org/apa/d/sacramento-cats-and-dogs-ok-visit-your/7407004501.html',
#   'https://sacramento.craigslist.org/apa/d/elk-grove-2bd-2ba-easy-access-to/7407004374.html',
#   'https://sacramento.craigslist.org/apa/d/sacramento-luxurious-bedroom-with/7407002714.html',
#   'https://sacramento.craigslist.org/apa/d/sacramento-handicap-access-common-area/7393772108.html',
#   'https://sacramento.craigslist.org/apa/d/vacaville-controlled-entry-access/7407000437.html',
#   'https://sacramento.craigslist.org/apa/d/sacramento-updater-free-moving/7400353149.html',
#   'https://sacramento.craigslist.org/apa/d/rancho-cordova-ada-compliant-courtesy/7401491576.html',
#   'https://sacramento.craigslist.org/apa/d/elk-grove-bedroom-bath-available-for/7406998982.html',
#   'https://sacramento.craigslist.org/apa/d/auburn-bed-bath-next-to-downtown-auburn/7404098978.html',
#   'https://sacramento.craigslist.org/apa/d/sacramento-bedroom-oversized-walk-in/7406998175.html',
#   'https://sacramento.craigslist.org/apa/d/elk-grove-bd-ba-onsite-playground/7406990370.html',
#   'https://sacramento.craigslist.org/apa/d/roseville-dont-miss-this-deal-come-tour/7399195560.html',
#   'https://sacramento.craigslist.org/apa/d/rocklin-dont-miss-this-great-deal/7400368940.html',
#   'https://sacramento.craigslist.org/apa/d/rocklin-check-out-this-gorgeous-bedroom/7400370332.html',
#   'https://sacramento.craigslist.org/apa/d/sacramento-private-balcony-or-patio/7406996989.html',
#   'https://sacramento.craigslist.org/apa/d/roseville-spacious-bedroom-townhome/7399194570.html',
#   'https://sacramento.craigslist.org/apa/d/sacramento-59-pulsar-cir-sacramento-ca/7406944594.html',
#   'https://sacramento.craigslist.org/apa/d/fair-oaks-price-change-low-pricing-1548/7406995873.html',
#   'https://sacramento.craigslist.org/apa/d/sacramento-tennis-courts-great/7406994784.html',
#   'https://sacramento.craigslist.org/apa/d/sacramento-gorgeous-scenery-outdoor/7406994135.html',
#   'https://sacramento.craigslist.org/apa/d/woodland-bedroom-available-in-november/7394566011.html',
#   'https://sacramento.craigslist.org/apa/d/citrus-heights-wow-quartz-counter-tops/7406977480.html',
#   'https://sacramento.craigslist.org/apa/d/elk-grove-bd-community-rose-garden-in/7406992189.html',
#   'https://sacramento.craigslist.org/apa/d/sacramento-spacious-and-beautiful-newer/7404345456.html',
#   'https://sacramento.craigslist.org/apa/d/roseville-upscale-two-bedroom-condo-in/7406986630.html',
#   'https://sacramento.craigslist.org/apa/d/sacramento-moving-fast-2bed-2baths/7406990601.html',
#   'https://sacramento.craigslist.org/apa/d/west-sacramento-amazing-bedroom-newly/7405880250.html',
#   'https://sacramento.craigslist.org/apa/d/elk-grove-onsite-playground-polished/7406989928.html',
#   'https://sacramento.craigslist.org/apa/d/vacaville-2bd-2ba-controlled-entry/7401474997.html',
#   'https://sacramento.craigslist.org/apa/d/elk-grove-price-drop-bedroom-bath-with/7406988821.html',
#   'https://sacramento.craigslist.org/apa/d/el-dorado-hills-because-location-really/7403881606.html',
#   'https://sacramento.craigslist.org/apa/d/sacramento-bedroom-renovated-italian/7406981199.html',
#   'https://sacramento.craigslist.org/apa/d/elk-grove-bedroom-bath-with-gorgeous/7406986180.html',
#   'https://sacramento.craigslist.org/apa/d/carmichael-willow-run-is-home/7406984964.html',
#   'https://sacramento.craigslist.org/apa/d/el-dorado-hills-everything-youve-been/7397691648.html',
#   'https://sacramento.craigslist.org/apa/d/fair-oaks-in-home-washer-and-dryer-lush/7406973056.html',
#   'https://sacramento.craigslist.org/apa/d/fair-oaks-flexible-lease-terms/7406974232.html',
#   'https://sacramento.craigslist.org/apa/d/sacramento-beautiful-bedroom-apartments/7394958949.html',
#   'https://sacramento.craigslist.org/apa/d/sacramento-bilt-rewards-earn-points-on/7395107322.html',
#   'https://sacramento.craigslist.org/apa/d/rio-linda-dishwasher-disposal/7406975265.html',
#   'https://sacramento.craigslist.org/apa/d/fair-oaks-bed-in-home-washer-and-dryer/7406975203.html',
#   'https://sacramento.craigslist.org/apa/d/carmichael-spacious-bedroom-december/7406976484.html',
#   'https://sacramento.craigslist.org/apa/d/sacramento-covered-parking-for-all/7406961837.html',
#   'https://sacramento.craigslist.org/apa/d/fair-oaks-available-now-large-bedroom/7406979692.html',
#   'https://sacramento.craigslist.org/apa/d/sacramento-ceiling-fan-in-living-area/7393667077.html',
#   'https://sacramento.craigslist.org/apa/d/davis-bedroom-full-bath-duplex-quiet/7406978935.html',
#   'https://sacramento.craigslist.org/apa/d/rancho-cordova-courtesy-patrol/7394572165.html',
#   'https://sacramento.craigslist.org/apa/d/fair-oaks-in-home-washer-and-dryer-lush/7406971914.html',
#   'https://sacramento.craigslist.org/apa/d/davis-private-furnished-rooms-at/7406976521.html',
#   'https://sacramento.craigslist.org/apa/d/el-dorado-hills-huge-dog-park-in/7400821202.html',
#   'https://sacramento.craigslist.org/apa/d/sacramento-nice-spacious-3bed-2bath-one/7405691293.html',
#   'https://sacramento.craigslist.org/apa/d/sacramento-bedroom-bath-house-lutheran/7405267256.html',
#   'https://sacramento.craigslist.org/apa/d/sacramento-quiet-1x1-with-huge-balcony/7406975736.html',
#   'https://sacramento.craigslist.org/apa/d/fair-oaks-two-bedroom-in-old-fair-oaks/7406064533.html',
#   'https://sacramento.craigslist.org/apa/d/fair-oaks-one-bedroom-one-bath/7406064771.html',
#   'https://sacramento.craigslist.org/apa/d/sacramento-flexible-short-term-lease/7397748541.html',
#   'https://sacramento.craigslist.org/apa/d/davis-last-unit-for-the-fall-season/7406969853.html',
#   'https://sacramento.craigslist.org/apa/d/vacaville-come-view-our-bed-bath/7406969201.html',
#   'https://sacramento.craigslist.org/apa/d/price-drop-on-gorgeous-2x2-attached/7406968737.html',
#   'https://sacramento.craigslist.org/apa/d/vacaville-2b-2b-available-for-rent/7402985839.html',
#   'https://sacramento.craigslist.org/apa/d/carmichael-perfect-place-to-live-is/7406967111.html',
#   'https://sacramento.craigslist.org/apa/d/sacramento-1944-bowling-green-dr-beds1/7406967012.html',
#   'https://sacramento.craigslist.org/apa/d/fair-oaks-bd-in-home-washer-and-dryer/7404495869.html',
#   'https://sacramento.craigslist.org/apa/d/luxury-bedrooms-with-full-size-washer/7406965787.html',
#   'https://sacramento.craigslist.org/apa/d/sacramento-beds1-bath-1944-bowling/7406964786.html',
#   'https://sacramento.craigslist.org/apa/d/orangevale-double-sink-evening-courtesy/7406955657.html',
#   'https://sacramento.craigslist.org/apa/d/sacramento-the-wait-is-over-moving-made/7395991450.html',
#   'https://sacramento.craigslist.org/apa/d/sacramento-modern-and-stunning-open/7406952697.html',
#   'https://sacramento.craigslist.org/apa/d/davis-fall-2022-is-coming-near-secure/7406956671.html',
#   'https://sacramento.craigslist.org/apa/d/fair-oaks-elegant-indoor-outdoor-living/7404727589.html',
#   'https://sacramento.craigslist.org/apa/d/elk-grove-ceramic-tile-front-entry-high/7403171230.html',
#   'https://sacramento.craigslist.org/apa/d/rancho-cordova-ada-compliant-basketball/7397856584.html',
#   'https://sacramento.craigslist.org/apa/d/sacramento-newly-renovated-bedrooms-bath/7406957842.html',
#   'https://sacramento.craigslist.org/apa/d/sacramento-gorgeous-and-affordable/7397870781.html',
#   'https://sacramento.craigslist.org/apa/d/fair-oaks-two-bedroom-in-old-fair-oaks/7397606297.html',
#   'https://sacramento.craigslist.org/apa/d/fair-oaks-one-bedroom-one-bath/7406954734.html',
#   'https://sacramento.craigslist.org/apa/d/sacramento-refrigerator-laundry/7406954468.html',
#   'https://sacramento.craigslist.org/apa/d/elk-grove-bedroom-house-with-acreage-lot/7402104943.html'])

# %%
link = links[0]
link

response = requests.get(link)
try:
    response.raise_for_status()
except:
    print("The url couldn't be downloaded!")

html = lx.fromstring(response.text)

price = html.xpath("//*[contains(@class, 'price')]")[0]
price

# Alternative using CSS selectors:
# html.cssselect(".price") 

title = html.cssselect("#titletextonly")[0].text_content()

#html.cssselect("p.attrgroup span")
[x.text_content() for x in html.xpath("//p[contains(@class, 'attrgroup')]/span")]
# Out:
# ['3BR / 2.5Ba',
#  '1366ft2',
#  'available nov 15',
#  'cats are OK - purrr',
#  'dogs are OK - wooof',
#  'flooring: tile',
#  'house',
#  'w/d hookups',
#  'no smoking',
#  'attached garage',
#  'rent period: monthly']
