# %% [markdown]
# # Lecture 7
#
# January 23, 2022
#
#
# ### Announcements
#
# * Submit project proposal on Canvas
# * Assignment 2 due next week
#
# ### Topics
#
# * Query Strings
# * API Keys
# * Undocumented APIs
#
# ### Datasets
#
# * [iTunes Search API](https://affiliate.itunes.apple.com/resources/documentation/itunes-store-web-service-search-api/)
# * [The Guardian API](https://open-platform.theguardian.com/)
# * [Yolo County Health Inspections](https://yoloeco.envisionconnect.com/)
#
#
# ### References
#
# * [__requests__ documentation](http://docs.python-requests.org/en/master/)
# * Python for Data Analysis, Ch. 6
#
# [PDSH]: https://jakevdp.github.io/PythonDataScienceHandbook/
# [ProGit]: https://git-scm.com/book/

# %% [markdown]
# ## Example Questions
#
# Did Biden or Trump get more newspaper coverage in the days leading up to the 2020 U.S. presidential election?

# %% [markdown]
# ## Authentication

# %% [markdown]
# ### API Keys
#
# Many APIs use a _key_ or _token_ to identify the user.
#
# For instance, The Guardian, a British newspaper, provides a [web API](https://open-platform.theguardian.com/) to access their news articles. You need an API key to use their web APIs. You can get one for free [here](https://bonobo.capi.gutools.co.uk/register/developer).
#
# #### Storing API Keys
#
# Your API key is private and your responsibility. Treat it like a password. Keep it secret!
#
# In order to keep your API key separate from your code:
# 1. Save the API key in a text file.
# 2. Use Python to load the API key into a variable.
#
# Python's built-in `open()` function opens a file, and the `.readline()` method reads a line from a file. Often you'll see these used with `with`, which automatically closes the file at the end of the block:

# %%
def read_key(keyfile):
    with open(keyfile) as f:
        return f.readline().strip("\n")

# %%
# Don't print out your actual API key
# print(read_key("api-keys/example"))

key = read_key("api-keys/guardian.txt")

# %%
type(key)
# Out:
# str

# %% [markdown]
# Now you can use the `key` variable anywhere you need the actual API key.

# %% [markdown]
# #### Querying The Guardian
#
# We've got our key, so let's use The Guardian API to answer our question about media coverage of Biden and Trump.
#
# Let's start by trying to get all of the articles about one of the candidates.

# %%
import requests

# %%
response = requests.get("https://content.guardianapis.com/search", params = {
        "api-key": key,
        "q": "Biden",
        "from-date": "2020-11-01",
        "to-date": "2020-11-10",
        "page-size": 50,
        "page": 1
    })

# %%
response.raise_for_status()

# %%
def get_articles(q, page = 1, from_date = "2020-11-01"):
    response = requests.get("https://content.guardianapis.com/search", params = {
        "api-key": key,
        "q": q,
        "from-date": from_date,
        "to-date": "2020-11-10",
        "page-size": 50,
        "page": page
    })
    response.raise_for_status()
    return response.json()["response"]

# %%
biden = get_articles("Biden")

# %%
biden
# Out:
# {'status': 'ok',
#  'userTier': 'developer',
#  'total': 474,
#  'startIndex': 1,
#  'pageSize': 50,
#  'currentPage': 1,
#  'pages': 10,
#  'orderBy': 'relevance',
#  'results': [{'id': 'australia-news/2020/nov/05/biden-edges-closer-to-victory',
#    'type': 'article',
#    'sectionId': 'australia-news',
#    'sectionName': 'Australia news',
#    'webPublicationDate': '2020-11-05T05:38:22Z',
#    'webTitle': 'US election briefing for Australia: Biden edges closer to victory',
#    'webUrl': 'https://www.theguardian.com/australia-news/2020/nov/05/biden-edges-closer-to-victory',
#    'apiUrl': 'https://content.guardianapis.com/australia-news/2020/nov/05/biden-edges-closer-to-victory',
#    'isHosted': False,
#    'pillarId': 'pillar/news',
#    'pillarName': 'News'},
#   {'id': 'politics/2020/nov/10/johnsons-biden-win-tweet-contains-hidden-trump-congratulations',
#    'type': 'article',
#    'sectionId': 'politics',
#    'sectionName': 'Politics',
#    'webPublicationDate': '2020-11-10T13:19:16Z',
#    'webTitle': "Johnson's Biden win tweet contains hidden Trump congratulations",
#    'webUrl': 'https://www.theguardian.com/politics/2020/nov/10/johnsons-biden-win-tweet-contains-hidden-trump-congratulations',
#    'apiUrl': 'https://content.guardianapis.com/politics/2020/nov/10/johnsons-biden-win-tweet-contains-hidden-trump-congratulations',
#    'isHosted': False,
#    'pillarId': 'pillar/news',
#    'pillarName': 'News'},
#   {'id': 'us-news/live/2020/nov/07/us-election-joe-biden-wins-presidency-donald-trump-kamala-harris-2020-latest-updates',
#    'type': 'liveblog',
#    'sectionId': 'us-news',
#    'sectionName': 'US news',
#    'webPublicationDate': '2020-11-08T10:04:24Z',
#    'webTitle': 'Biden addresses Americans after victory – as it happened',
#    'webUrl': 'https://www.theguardian.com/us-news/live/2020/nov/07/us-election-joe-biden-wins-presidency-donald-trump-kamala-harris-2020-latest-updates',
#    'apiUrl': 'https://content.guardianapis.com/us-news/live/2020/nov/07/us-election-joe-biden-wins-presidency-donald-trump-kamala-harris-2020-latest-updates',
#    'isHosted': False,
#    'pillarId': 'pillar/news',
#    'pillarName': 'News'},
#   {'id': 'us-news/2020/nov/08/donald-trump-concede-legal-challenge-republicans-joe-biden-golf',
#    'type': 'article',
#    'sectionId': 'us-news',
#    'sectionName': 'US news',
#    'webPublicationDate': '2020-11-08T19:39:23Z',
#    'webTitle': 'Republicans back Trump challenge to Biden election victory',
#    'webUrl': 'https://www.theguardian.com/us-news/2020/nov/08/donald-trump-concede-legal-challenge-republicans-joe-biden-golf',
#    'apiUrl': 'https://content.guardianapis.com/us-news/2020/nov/08/donald-trump-concede-legal-challenge-republicans-joe-biden-golf',
#    'isHosted': False,
#    'pillarId': 'pillar/news',
#    'pillarName': 'News'},
#   {'id': 'us-news/2020/nov/07/joe-biden-disunited-states-of-america',
#    'type': 'article',
#    'sectionId': 'us-news',
#    'sectionName': 'US news',
#    'webPublicationDate': '2020-11-07T10:00:07Z',
#    'webTitle': 'Joe Biden poised to inherit Disunited States of America',
#    'webUrl': 'https://www.theguardian.com/us-news/2020/nov/07/joe-biden-disunited-states-of-america',
#    'apiUrl': 'https://content.guardianapis.com/us-news/2020/nov/07/joe-biden-disunited-states-of-america',
#    'isHosted': False,
#    'pillarId': 'pillar/news',
#    'pillarName': 'News'},
#   {'id': 'business/2020/nov/05/global-stock-markets-climb-on-prospect-of-biden-presidency',
#    'type': 'article',
#    'sectionId': 'business',
#    'sectionName': 'Business',
#    'webPublicationDate': '2020-11-05T05:57:36Z',
#    'webTitle': 'Global stock markets climb on prospect of Biden presidency',
#    'webUrl': 'https://www.theguardian.com/business/2020/nov/05/global-stock-markets-climb-on-prospect-of-biden-presidency',
#    'apiUrl': 'https://content.guardianapis.com/business/2020/nov/05/global-stock-markets-climb-on-prospect-of-biden-presidency',
#    'isHosted': False,
#    'pillarId': 'pillar/news',
#    'pillarName': 'News'},
#   {'id': 'world/2020/nov/09/monday-briefing-biden-to-make-covid-top-priority',
#    'type': 'article',
#    'sectionId': 'world',
#    'sectionName': 'World news',
#    'webPublicationDate': '2020-11-09T06:24:26Z',
#    'webTitle': 'Monday briefing: Biden to make Covid top priority',
#    'webUrl': 'https://www.theguardian.com/world/2020/nov/09/monday-briefing-biden-to-make-covid-top-priority',
#    'apiUrl': 'https://content.guardianapis.com/world/2020/nov/09/monday-briefing-biden-to-make-covid-top-priority',
#    'isHosted': False,
#    'pillarId': 'pillar/news',
#    'pillarName': 'News'},
#   {'id': 'us-news/2020/nov/08/joe-biden-trauma-and-triumph-the-10-moments-that-made-him',
#    'type': 'article',
#    'sectionId': 'us-news',
#    'sectionName': 'US news',
#    'webPublicationDate': '2020-11-08T12:33:41Z',
#    'webTitle': 'Trauma and triumph: the 10 moments that made Joe Biden',
#    'webUrl': 'https://www.theguardian.com/us-news/2020/nov/08/joe-biden-trauma-and-triumph-the-10-moments-that-made-him',
#    'apiUrl': 'https://content.guardianapis.com/us-news/2020/nov/08/joe-biden-trauma-and-triumph-the-10-moments-that-made-him',
#    'isHosted': False,
#    'pillarId': 'pillar/news',
#    'pillarName': 'News'},
#   {'id': 'us-news/2020/nov/08/joe-biden-paris-climate-goals-0-1c',
#    'type': 'article',
#    'sectionId': 'environment',
#    'sectionName': 'Environment',
#    'webPublicationDate': '2020-11-08T11:32:04Z',
#    'webTitle': "Joe Biden could bring Paris climate goals 'within striking distance'",
#    'webUrl': 'https://www.theguardian.com/us-news/2020/nov/08/joe-biden-paris-climate-goals-0-1c',
#    'apiUrl': 'https://content.guardianapis.com/us-news/2020/nov/08/joe-biden-paris-climate-goals-0-1c',
#    'isHosted': False,
#    'pillarId': 'pillar/news',
#    'pillarName': 'News'},
#   {'id': 'us-news/2020/nov/05/fox-draws-trump-campaigns-ire-after-early-call-of-arizona-for-biden',
#    'type': 'article',
#    'sectionId': 'us-news',
#    'sectionName': 'US news',
#    'webPublicationDate': '2020-11-05T14:07:08Z',
#    'webTitle': "Fox draws Trump campaign's ire after calling Arizona for Biden",
#    'webUrl': 'https://www.theguardian.com/us-news/2020/nov/05/fox-draws-trump-campaigns-ire-after-early-call-of-arizona-for-biden',
#    'apiUrl': 'https://content.guardianapis.com/us-news/2020/nov/05/fox-draws-trump-campaigns-ire-after-early-call-of-arizona-for-biden',
#    'isHosted': False,
#    'pillarId': 'pillar/news',
#    'pillarName': 'News'},
#   {'id': 'us-news/2020/nov/04/trump-wins-florida-2020-election-biden',
#    'type': 'article',
#    'sectionId': 'us-news',
#    'sectionName': 'US news',
#    'webPublicationDate': '2020-11-04T06:50:49Z',
#    'webTitle': 'Trump wins swing state Florida in setback for Biden campaign',
#    'webUrl': 'https://www.theguardian.com/us-news/2020/nov/04/trump-wins-florida-2020-election-biden',
#    'apiUrl': 'https://content.guardianapis.com/us-news/2020/nov/04/trump-wins-florida-2020-election-biden',
#    'isHosted': False,
#    'pillarId': 'pillar/news',
#    'pillarName': 'News'},
#   {'id': 'music/2020/nov/03/lady-gaga-attacks-donald-trump-at-joe-biden-rally',
#    'type': 'article',
#    'sectionId': 'music',
#    'sectionName': 'Music',
#    'webPublicationDate': '2020-11-03T09:07:48Z',
#    'webTitle': "Lady Gaga attacks Trump's 'grab' remarks at Joe Biden rally",
#    'webUrl': 'https://www.theguardian.com/music/2020/nov/03/lady-gaga-attacks-donald-trump-at-joe-biden-rally',
#    'apiUrl': 'https://content.guardianapis.com/music/2020/nov/03/lady-gaga-attacks-donald-trump-at-joe-biden-rally',
#    'isHosted': False,
#    'pillarId': 'pillar/arts',
#    'pillarName': 'Arts'},
#   {'id': 'tv-and-radio/2020/nov/03/tv-tonight-the-moment-of-truth-for-trump-and-biden',
#    'type': 'article',
#    'sectionId': 'tv-and-radio',
#    'sectionName': 'Television & radio',
#    'webPublicationDate': '2020-11-03T06:00:49Z',
#    'webTitle': 'TV tonight: the moment of truth  for Trump and Biden',
#    'webUrl': 'https://www.theguardian.com/tv-and-radio/2020/nov/03/tv-tonight-the-moment-of-truth-for-trump-and-biden',
#    'apiUrl': 'https://content.guardianapis.com/tv-and-radio/2020/nov/03/tv-tonight-the-moment-of-truth-for-trump-and-biden',
#    'isHosted': False,
#    'pillarId': 'pillar/arts',
#    'pillarName': 'Arts'},
#   {'id': 'us-news/ng-interactive/2020/nov/07/how-did-joe-biden-win-presidency-visual-guide',
#    'type': 'interactive',
#    'sectionId': 'us-news',
#    'sectionName': 'US news',
#    'webPublicationDate': '2020-11-09T10:35:17Z',
#    'webTitle': 'How Joe Biden won the presidency – a visual guide',
#    'webUrl': 'https://www.theguardian.com/us-news/ng-interactive/2020/nov/07/how-did-joe-biden-win-presidency-visual-guide',
#    'apiUrl': 'https://content.guardianapis.com/us-news/ng-interactive/2020/nov/07/how-did-joe-biden-win-presidency-visual-guide',
#    'isHosted': False,
#    'pillarId': 'pillar/news',
#    'pillarName': 'News'},
#   {'id': 'commentisfree/2020/nov/09/the-guardian-view-on-johnsons-biden-problem-not-going-away',
#    'type': 'article',
#    'sectionId': 'commentisfree',
#    'sectionName': 'Opinion',
#    'webPublicationDate': '2020-11-09T19:25:48Z',
#    'webTitle': "The Guardian view on Johnson's Biden problem: not going away | Editorial",
#    'webUrl': 'https://www.theguardian.com/commentisfree/2020/nov/09/the-guardian-view-on-johnsons-biden-problem-not-going-away',
#    'apiUrl': 'https://content.guardianapis.com/commentisfree/2020/nov/09/the-guardian-view-on-johnsons-biden-problem-not-going-away',
#    'isHosted': False,
#    'pillarId': 'pillar/opinion',
#    'pillarName': 'Opinion'},
#   {'id': 'business/2020/nov/09/biden-win-boosts-global-stock-markets-as-japanese-shares-soar-to-29-year-high',
#    'type': 'article',
#    'sectionId': 'business',
#    'sectionName': 'Business',
#    'webPublicationDate': '2020-11-09T10:24:55Z',
#    'webTitle': 'Biden win boosts global stock markets as FTSE 100 surges',
#    'webUrl': 'https://www.theguardian.com/business/2020/nov/09/biden-win-boosts-global-stock-markets-as-japanese-shares-soar-to-29-year-high',
#    'apiUrl': 'https://content.guardianapis.com/business/2020/nov/09/biden-win-boosts-global-stock-markets-as-japanese-shares-soar-to-29-year-high',
#    'isHosted': False,
#    'pillarId': 'pillar/news',
#    'pillarName': 'News'},
#   {'id': 'politics/2020/nov/09/uk-risks-becoming-international-pariah-by-rewriting-brexit-bill',
#    'type': 'article',
#    'sectionId': 'politics',
#    'sectionName': 'Politics',
#    'webPublicationDate': '2020-11-09T09:15:47Z',
#    'webTitle': "Brexit: UK risks being 'international pariah' under Biden, says Labour",
#    'webUrl': 'https://www.theguardian.com/politics/2020/nov/09/uk-risks-becoming-international-pariah-by-rewriting-brexit-bill',
#    'apiUrl': 'https://content.guardianapis.com/politics/2020/nov/09/uk-risks-becoming-international-pariah-by-rewriting-brexit-bill',
#    'isHosted': False,
#    'pillarId': 'pillar/news',
#    'pillarName': 'News'},
#   {'id': 'us-news/2020/nov/10/joe-biden-donald-trump-never-see-again-valerie-biden-owens-interview-axios',
#    'type': 'article',
#    'sectionId': 'us-news',
#    'sectionName': 'US news',
#    'webPublicationDate': '2020-11-10T14:13:51Z',
#    'webTitle': 'Biden ‘never going to see Trump again’ after inauguration, says sister',
#    'webUrl': 'https://www.theguardian.com/us-news/2020/nov/10/joe-biden-donald-trump-never-see-again-valerie-biden-owens-interview-axios',
#    'apiUrl': 'https://content.guardianapis.com/us-news/2020/nov/10/joe-biden-donald-trump-never-see-again-valerie-biden-owens-interview-axios',
#    'isHosted': False,
#    'pillarId': 'pillar/news',
#    'pillarName': 'News'},
#   {'id': 'us-news/2020/nov/03/biden-sweeps-board-in-tiny-new-hampshire-village-dixville-notch',
#    'type': 'article',
#    'sectionId': 'us-news',
#    'sectionName': 'US news',
#    'webPublicationDate': '2020-11-03T12:56:42Z',
#    'webTitle': 'Biden sweeps board in tiny New Hampshire village Dixville Notch',
#    'webUrl': 'https://www.theguardian.com/us-news/2020/nov/03/biden-sweeps-board-in-tiny-new-hampshire-village-dixville-notch',
#    'apiUrl': 'https://content.guardianapis.com/us-news/2020/nov/03/biden-sweeps-board-in-tiny-new-hampshire-village-dixville-notch',
#    'isHosted': False,
#    'pillarId': 'pillar/news',
#    'pillarName': 'News'},
#   {'id': 'us-news/live/2020/nov/05/us-election-joe-biden-donald-trump-result-latest-who-is-winning-live-2020-updates',
#    'type': 'liveblog',
#    'sectionId': 'us-news',
#    'sectionName': 'US news',
#    'webPublicationDate': '2020-11-06T19:33:10Z',
#    'webTitle': 'Growing lead for Biden in Nevada and Pennsylvania\xa0– as it happened',
#    'webUrl': 'https://www.theguardian.com/us-news/live/2020/nov/05/us-election-joe-biden-donald-trump-result-latest-who-is-winning-live-2020-updates',
#    'apiUrl': 'https://content.guardianapis.com/us-news/live/2020/nov/05/us-election-joe-biden-donald-trump-result-latest-who-is-winning-live-2020-updates',
#    'isHosted': False,
#    'pillarId': 'pillar/news',
#    'pillarName': 'News'},
#   {'id': 'us-news/2020/nov/04/us-election-takeaways-biden-trump-polls',
#    'type': 'article',
#    'sectionId': 'us-news',
#    'sectionName': 'US news',
#    'webPublicationDate': '2020-11-04T17:59:06Z',
#    'webTitle': 'Six key election takeaways – about Biden, Trump and those misleading polls',
#    'webUrl': 'https://www.theguardian.com/us-news/2020/nov/04/us-election-takeaways-biden-trump-polls',
#    'apiUrl': 'https://content.guardianapis.com/us-news/2020/nov/04/us-election-takeaways-biden-trump-polls',
#    'isHosted': False,
#    'pillarId': 'pillar/news',
#    'pillarName': 'News'},
#   {'id': 'world/2020/nov/04/wednesday-briefing-biden-i-believe-we-are-on-track-to-win',
#    'type': 'article',
#    'sectionId': 'world',
#    'sectionName': 'World news',
#    'webPublicationDate': '2020-11-04T06:30:25Z',
#    'webTitle': "Wednesday briefing: Biden – 'I believe we are on track to win'",
#    'webUrl': 'https://www.theguardian.com/world/2020/nov/04/wednesday-briefing-biden-i-believe-we-are-on-track-to-win',
#    'apiUrl': 'https://content.guardianapis.com/world/2020/nov/04/wednesday-briefing-biden-i-believe-we-are-on-track-to-win',
#    'isHosted': False,
#    'pillarId': 'pillar/news',
#    'pillarName': 'News'},
#   {'id': 'us-news/2020/nov/10/joe-biden-trump-embarrassment-refusal-to-concede-election',
#    'type': 'article',
#    'sectionId': 'us-news',
#    'sectionName': 'US news',
#    'webPublicationDate': '2020-11-10T22:45:45Z',
#    'webTitle': "'An embarrassment': Joe Biden criticizes Trump's refusal to concede election",
#    'webUrl': 'https://www.theguardian.com/us-news/2020/nov/10/joe-biden-trump-embarrassment-refusal-to-concede-election',
#    'apiUrl': 'https://content.guardianapis.com/us-news/2020/nov/10/joe-biden-trump-embarrassment-refusal-to-concede-election',
#    'isHosted': False,
#    'pillarId': 'pillar/news',
#    'pillarName': 'News'},
#   {'id': 'us-news/2020/nov/08/russia-and-china-silence-speaks-volumes-as-leaders-congratulate-biden',
#    'type': 'article',
#    'sectionId': 'us-news',
#    'sectionName': 'US news',
#    'webPublicationDate': '2020-11-08T17:46:38Z',
#    'webTitle': 'Russia and China silence speaks volumes as leaders congratulate Biden',
#    'webUrl': 'https://www.theguardian.com/us-news/2020/nov/08/russia-and-china-silence-speaks-volumes-as-leaders-congratulate-biden',
#    'apiUrl': 'https://content.guardianapis.com/us-news/2020/nov/08/russia-and-china-silence-speaks-volumes-as-leaders-congratulate-biden',
#    'isHosted': False,
#    'pillarId': 'pillar/news',
#    'pillarName': 'News'},
#   {'id': 'commentisfree/2020/nov/08/its-president-biden-what-a-relief-for-the-whole-world',
#    'type': 'article',
#    'sectionId': 'commentisfree',
#    'sectionName': 'Opinion',
#    'webPublicationDate': '2020-11-07T20:23:07Z',
#    'webTitle': "It's PRESIDENT BIDEN! What a 'relief' for the whole world! | First Dog on the Moon",
#    'webUrl': 'https://www.theguardian.com/commentisfree/2020/nov/08/its-president-biden-what-a-relief-for-the-whole-world',
#    'apiUrl': 'https://content.guardianapis.com/commentisfree/2020/nov/08/its-president-biden-what-a-relief-for-the-whole-world',
#    'isHosted': False,
#    'pillarId': 'pillar/opinion',
#    'pillarName': 'Opinion'},
#   {'id': 'world/2020/nov/05/thursday-briefing-biden-with-one-hand-on-the-prize',
#    'type': 'article',
#    'sectionId': 'world',
#    'sectionName': 'World news',
#    'webPublicationDate': '2020-11-05T06:32:05Z',
#    'webTitle': 'Thursday briefing: Joe Biden with one hand on the prize',
#    'webUrl': 'https://www.theguardian.com/world/2020/nov/05/thursday-briefing-biden-with-one-hand-on-the-prize',
#    'apiUrl': 'https://content.guardianapis.com/world/2020/nov/05/thursday-briefing-biden-with-one-hand-on-the-prize',
#    'isHosted': False,
#    'pillarId': 'pillar/news',
#    'pillarName': 'News'},
#   {'id': 'business/2020/nov/03/stock-markets-soar-as-city-traders-anticipate-joe-biden-win',
#    'type': 'article',
#    'sectionId': 'business',
#    'sectionName': 'Business',
#    'webPublicationDate': '2020-11-03T13:17:26Z',
#    'webTitle': 'Stock markets soar as City traders anticipate Joe Biden win',
#    'webUrl': 'https://www.theguardian.com/business/2020/nov/03/stock-markets-soar-as-city-traders-anticipate-joe-biden-win',
#    'apiUrl': 'https://content.guardianapis.com/business/2020/nov/03/stock-markets-soar-as-city-traders-anticipate-joe-biden-win',
#    'isHosted': False,
#    'pillarId': 'pillar/news',
#    'pillarName': 'News'},
#   {'id': 'world/2020/nov/02/monday-briefing-biden-v-trump-final-countdown-to-us-election',
#    'type': 'article',
#    'sectionId': 'world',
#    'sectionName': 'World news',
#    'webPublicationDate': '2020-11-02T06:31:39Z',
#    'webTitle': 'Monday briefing: Biden v Trump – final countdown to US election',
#    'webUrl': 'https://www.theguardian.com/world/2020/nov/02/monday-briefing-biden-v-trump-final-countdown-to-us-election',
#    'apiUrl': 'https://content.guardianapis.com/world/2020/nov/02/monday-briefing-biden-v-trump-final-countdown-to-us-election',
#    'isHosted': False,
#    'pillarId': 'pillar/news',
#    'pillarName': 'News'},
#   {'id': 'politics/2020/nov/10/boris-johnson-phones-to-congratulate-joe-biden-and-discuss-close-relationship',
#    'type': 'article',
#    'sectionId': 'politics',
#    'sectionName': 'Politics',
#    'webPublicationDate': '2020-11-10T21:17:18Z',
#    'webTitle': "Boris Johnson phones to congratulate Joe Biden and discuss 'close' relationship",
#    'webUrl': 'https://www.theguardian.com/politics/2020/nov/10/boris-johnson-phones-to-congratulate-joe-biden-and-discuss-close-relationship',
#    'apiUrl': 'https://content.guardianapis.com/politics/2020/nov/10/boris-johnson-phones-to-congratulate-joe-biden-and-discuss-close-relationship',
#    'isHosted': False,
#    'pillarId': 'pillar/news',
#    'pillarName': 'News'},
#   {'id': 'society/2020/nov/10/reproductive-health-ngos-abortion-pin-hopes-on-biden-reversing-global-gag-rule',
#    'type': 'article',
#    'sectionId': 'society',
#    'sectionName': 'Society',
#    'webPublicationDate': '2020-11-10T11:28:23Z',
#    'webTitle': 'Reproductive health NGOs pin hopes on Biden reversing ‘global gag rule’',
#    'webUrl': 'https://www.theguardian.com/society/2020/nov/10/reproductive-health-ngos-abortion-pin-hopes-on-biden-reversing-global-gag-rule',
#    'apiUrl': 'https://content.guardianapis.com/society/2020/nov/10/reproductive-health-ngos-abortion-pin-hopes-on-biden-reversing-global-gag-rule',
#    'isHosted': False,
#    'pillarId': 'pillar/news',
#    'pillarName': 'News'},
#   {'id': 'australia-news/2020/nov/09/biden-era-begins-but-trump-fights-on-in-his-own-world',
#    'type': 'article',
#    'sectionId': 'australia-news',
#    'sectionName': 'Australia news',
#    'webPublicationDate': '2020-11-09T05:35:34Z',
#    'webTitle': 'US election briefing for Australia: Biden era begins, but Trump fights on in his own world',
#    'webUrl': 'https://www.theguardian.com/australia-news/2020/nov/09/biden-era-begins-but-trump-fights-on-in-his-own-world',
#    'apiUrl': 'https://content.guardianapis.com/australia-news/2020/nov/09/biden-era-begins-but-trump-fights-on-in-his-own-world',
#    'isHosted': False,
#    'pillarId': 'pillar/news',
#    'pillarName': 'News'},
#   {'id': 'commentisfree/2020/nov/08/joe-biden-donald-trump-election-healing-robert-reich',
#    'type': 'article',
#    'sectionId': 'commentisfree',
#    'sectionName': 'Opinion',
#    'webPublicationDate': '2020-11-08T06:00:31Z',
#    'webTitle': 'How can Biden heal America when Trump doesn’t want it healed? | Robert Reich',
#    'webUrl': 'https://www.theguardian.com/commentisfree/2020/nov/08/joe-biden-donald-trump-election-healing-robert-reich',
#    'apiUrl': 'https://content.guardianapis.com/commentisfree/2020/nov/08/joe-biden-donald-trump-election-healing-robert-reich',
#    'isHosted': False,
#    'pillarId': 'pillar/opinion',
#    'pillarName': 'Opinion'},
#   {'id': 'us-news/2020/nov/07/trump-supporters-protest-pennsylvania-michigan',
#    'type': 'article',
#    'sectionId': 'us-news',
#    'sectionName': 'US news',
#    'webPublicationDate': '2020-11-08T03:27:53Z',
#    'webTitle': "'It's not over': Trump supporters protest Biden victory in swing states",
#    'webUrl': 'https://www.theguardian.com/us-news/2020/nov/07/trump-supporters-protest-pennsylvania-michigan',
#    'apiUrl': 'https://content.guardianapis.com/us-news/2020/nov/07/trump-supporters-protest-pennsylvania-michigan',
#    'isHosted': False,
#    'pillarId': 'pillar/news',
#    'pillarName': 'News'},
#   {'id': 'us-news/2020/nov/07/ever-resilient-president-joe-biden-finally-grasps-chance-lead-america',
#    'type': 'article',
#    'sectionId': 'us-news',
#    'sectionName': 'US news',
#    'webPublicationDate': '2020-11-07T16:32:29Z',
#    'webTitle': 'Ever resilient, Joe Biden finally grasps his chance to lead America',
#    'webUrl': 'https://www.theguardian.com/us-news/2020/nov/07/ever-resilient-president-joe-biden-finally-grasps-chance-lead-america',
#    'apiUrl': 'https://content.guardianapis.com/us-news/2020/nov/07/ever-resilient-president-joe-biden-finally-grasps-chance-lead-america',
#    'isHosted': False,
#    'pillarId': 'pillar/news',
#    'pillarName': 'News'},
#   {'id': 'us-news/2020/nov/08/joe-biden-coronavirus-taskforce',
#    'type': 'article',
#    'sectionId': 'us-news',
#    'sectionName': 'US news',
#    'webPublicationDate': '2020-11-08T16:22:16Z',
#    'webTitle': 'US posts fourth consecutive daily Covid record as Joe Biden prepares taskforce',
#    'webUrl': 'https://www.theguardian.com/us-news/2020/nov/08/joe-biden-coronavirus-taskforce',
#    'apiUrl': 'https://content.guardianapis.com/us-news/2020/nov/08/joe-biden-coronavirus-taskforce',
#    'isHosted': False,
#    'pillarId': 'pillar/news',
#    'pillarName': 'News'},
#   {'id': 'us-news/2020/nov/08/biden-transition-team-plans-executive-orders-covid-taskforce',
#    'type': 'article',
#    'sectionId': 'us-news',
#    'sectionName': 'US news',
#    'webPublicationDate': '2020-11-08T15:07:18Z',
#    'webTitle': "Joe Biden faces rocky transition as work of undoing Trump's damage begins",
#    'webUrl': 'https://www.theguardian.com/us-news/2020/nov/08/biden-transition-team-plans-executive-orders-covid-taskforce',
#    'apiUrl': 'https://content.guardianapis.com/us-news/2020/nov/08/biden-transition-team-plans-executive-orders-covid-taskforce',
#    'isHosted': False,
#    'pillarId': 'pillar/news',
#    'pillarName': 'News'},
#   {'id': 'politics/2020/nov/08/three-times-as-many-british-voters-favour-joe-biden-than-donald-trump',
#    'type': 'article',
#    'sectionId': 'politics',
#    'sectionName': 'Politics',
#    'webPublicationDate': '2020-11-08T06:20:31Z',
#    'webTitle': 'Three times as many British voters favour Joe Biden than Donald Trump',
#    'webUrl': 'https://www.theguardian.com/politics/2020/nov/08/three-times-as-many-british-voters-favour-joe-biden-than-donald-trump',
#    'apiUrl': 'https://content.guardianapis.com/politics/2020/nov/08/three-times-as-many-british-voters-favour-joe-biden-than-donald-trump',
#    'isHosted': False,
#    'pillarId': 'pillar/news',
#    'pillarName': 'News'},
#   {'id': 'us-news/2020/nov/07/trump-fox-news-joe-biden-rightwing-media',
#    'type': 'article',
#    'sectionId': 'us-news',
#    'sectionName': 'US news',
#    'webPublicationDate': '2020-11-07T23:28:02Z',
#    'webTitle': 'Loyal Trump outlets cry betrayal after Fox News calls election for Biden',
#    'webUrl': 'https://www.theguardian.com/us-news/2020/nov/07/trump-fox-news-joe-biden-rightwing-media',
#    'apiUrl': 'https://content.guardianapis.com/us-news/2020/nov/07/trump-fox-news-joe-biden-rightwing-media',
#    'isHosted': False,
#    'pillarId': 'pillar/news',
#    'pillarName': 'News'},
#   {'id': 'us-news/2020/nov/07/donald-trump-golf-course-joe-biden-election',
#    'type': 'article',
#    'sectionId': 'us-news',
#    'sectionName': 'US news',
#    'webPublicationDate': '2020-11-07T15:52:08Z',
#    'webTitle': 'Trump heads for golf club – again – before defeat by Biden is called',
#    'webUrl': 'https://www.theguardian.com/us-news/2020/nov/07/donald-trump-golf-course-joe-biden-election',
#    'apiUrl': 'https://content.guardianapis.com/us-news/2020/nov/07/donald-trump-golf-course-joe-biden-election',
#    'isHosted': False,
#    'pillarId': 'pillar/news',
#    'pillarName': 'News'},
#   {'id': 'us-news/2020/nov/02/trump-biden-supporters-campaign-bus',
#    'type': 'article',
#    'sectionId': 'us-news',
#    'sectionName': 'US news',
#    'webPublicationDate': '2020-11-02T16:53:34Z',
#    'webTitle': "Trump says supporters who harassed Biden campaign bus 'did nothing wrong'",
#    'webUrl': 'https://www.theguardian.com/us-news/2020/nov/02/trump-biden-supporters-campaign-bus',
#    'apiUrl': 'https://content.guardianapis.com/us-news/2020/nov/02/trump-biden-supporters-campaign-bus',
#    'isHosted': False,
#    'pillarId': 'pillar/news',
#    'pillarName': 'News'},
#   {'id': 'us-news/live/2020/nov/01/us-election-2020-donald-trump-joe-biden-mike-pence-kamala-harris-coronavirus-covid-19-live-updates',
#    'type': 'liveblog',
#    'sectionId': 'us-news',
#    'sectionName': 'US news',
#    'webPublicationDate': '2020-11-02T06:01:06Z',
#    'webTitle': 'FBI confirms it is investigating Biden bus incident – as it happened',
#    'webUrl': 'https://www.theguardian.com/us-news/live/2020/nov/01/us-election-2020-donald-trump-joe-biden-mike-pence-kamala-harris-coronavirus-covid-19-live-updates',
#    'apiUrl': 'https://content.guardianapis.com/us-news/live/2020/nov/01/us-election-2020-donald-trump-joe-biden-mike-pence-kamala-harris-coronavirus-covid-19-live-updates',
#    'isHosted': False,
#    'pillarId': 'pillar/news',
#    'pillarName': 'News'},
#   {'id': 'us-news/2020/nov/05/biden-trump-us-election-2020-votes-count',
#    'type': 'article',
#    'sectionId': 'us-news',
#    'sectionName': 'US news',
#    'webPublicationDate': '2020-11-06T10:13:03Z',
#    'webTitle': "Trump repeats false claim of election win as Biden calls for 'patience'",
#    'webUrl': 'https://www.theguardian.com/us-news/2020/nov/05/biden-trump-us-election-2020-votes-count',
#    'apiUrl': 'https://content.guardianapis.com/us-news/2020/nov/05/biden-trump-us-election-2020-votes-count',
#    'isHosted': False,
#    'pillarId': 'pillar/news',
#    'pillarName': 'News'},
#   {'id': 'us-news/2020/nov/03/joe-biden-campaign-election-night-event',
#    'type': 'article',
#    'sectionId': 'us-news',
#    'sectionName': 'US news',
#    'webPublicationDate': '2020-11-04T16:10:43Z',
#    'webTitle': "'We're on track to win': Biden expresses optimism as vote count continues",
#    'webUrl': 'https://www.theguardian.com/us-news/2020/nov/03/joe-biden-campaign-election-night-event',
#    'apiUrl': 'https://content.guardianapis.com/us-news/2020/nov/03/joe-biden-campaign-election-night-event',
#    'isHosted': False,
#    'pillarId': 'pillar/news',
#    'pillarName': 'News'},
#   {'id': 'us-news/ng-interactive/2020/oct/30/build-your-own-us-election-result-plot-a-win-for-biden-or-trump',
#    'type': 'interactive',
#    'sectionId': 'us-news',
#    'sectionName': 'US news',
#    'webPublicationDate': '2020-11-03T16:41:53Z',
#    'webTitle': 'Build your own US election result: plot a Biden or Trump win',
#    'webUrl': 'https://www.theguardian.com/us-news/ng-interactive/2020/oct/30/build-your-own-us-election-result-plot-a-win-for-biden-or-trump',
#    'apiUrl': 'https://content.guardianapis.com/us-news/ng-interactive/2020/oct/30/build-your-own-us-election-result-plot-a-win-for-biden-or-trump',
#    'isHosted': False,
#    'pillarId': 'pillar/news',
#    'pillarName': 'News'},
#   {'id': 'world/2020/nov/01/democracy-fascism-global-trump-biden-election',
#    'type': 'article',
#    'sectionId': 'world',
#    'sectionName': 'World news',
#    'webPublicationDate': '2020-11-01T16:00:24Z',
#    'webTitle': 'Scholars warn of collapse of democracy as Trump v Biden election looms',
#    'webUrl': 'https://www.theguardian.com/world/2020/nov/01/democracy-fascism-global-trump-biden-election',
#    'apiUrl': 'https://content.guardianapis.com/world/2020/nov/01/democracy-fascism-global-trump-biden-election',
#    'isHosted': False,
#    'pillarId': 'pillar/news',
#    'pillarName': 'News'},
#   {'id': 'world/2020/nov/09/his-speech-was-perfect-china-celebrates-biden-win-amid-hopes-for-warmer-ties',
#    'type': 'article',
#    'sectionId': 'world',
#    'sectionName': 'World news',
#    'webPublicationDate': '2020-11-09T14:02:07Z',
#    'webTitle': "'His speech was perfect': Chinese social media users celebrate Biden win",
#    'webUrl': 'https://www.theguardian.com/world/2020/nov/09/his-speech-was-perfect-china-celebrates-biden-win-amid-hopes-for-warmer-ties',
#    'apiUrl': 'https://content.guardianapis.com/world/2020/nov/09/his-speech-was-perfect-china-celebrates-biden-win-amid-hopes-for-warmer-ties',
#    'isHosted': False,
#    'pillarId': 'pillar/news',
#    'pillarName': 'News'},
#   {'id': 'politics/2020/nov/08/dominic-raab-joe-biden-no-deal-brexit',
#    'type': 'article',
#    'sectionId': 'politics',
#    'sectionName': 'Politics',
#    'webPublicationDate': '2020-11-08T13:54:39Z',
#    'webTitle': 'Johnson risks rift with Biden by pressing ahead with Brexit bill',
#    'webUrl': 'https://www.theguardian.com/politics/2020/nov/08/dominic-raab-joe-biden-no-deal-brexit',
#    'apiUrl': 'https://content.guardianapis.com/politics/2020/nov/08/dominic-raab-joe-biden-no-deal-brexit',
#    'isHosted': False,
#    'pillarId': 'pillar/news',
#    'pillarName': 'News'},
#   {'id': 'us-news/2020/nov/05/florida-latino-voters-joe-biden-donald-trump',
#    'type': 'article',
#    'sectionId': 'us-news',
#    'sectionName': 'US news',
#    'webPublicationDate': '2020-11-05T19:57:31Z',
#    'webTitle': "'Republicans built the base': how Joe Biden lost Florida's Latino voters",
#    'webUrl': 'https://www.theguardian.com/us-news/2020/nov/05/florida-latino-voters-joe-biden-donald-trump',
#    'apiUrl': 'https://content.guardianapis.com/us-news/2020/nov/05/florida-latino-voters-joe-biden-donald-trump',
#    'isHosted': False,
#    'pillarId': 'pillar/news',
#    'pillarName': 'News'},
#   {'id': 'us-news/2020/nov/04/democrats-senate-house-down-ballot-races-biden',
#    'type': 'article',
#    'sectionId': 'us-news',
#    'sectionName': 'US news',
#    'webPublicationDate': '2020-11-04T22:12:01Z',
#    'webTitle': 'Joe Biden bullish but down-ballot races deliver disappointment for Democrats',
#    'webUrl': 'https://www.theguardian.com/us-news/2020/nov/04/democrats-senate-house-down-ballot-races-biden',
#    'apiUrl': 'https://content.guardianapis.com/us-news/2020/nov/04/democrats-senate-house-down-ballot-races-biden',
#    'isHosted': False,
#    'pillarId': 'pillar/news',
#    'pillarName': 'News'},
#   {'id': 'us-news/2020/nov/09/first-thing-biden-gets-down-to-work-but-trump-still-not-budging',
#    'type': 'article',
#    'sectionId': 'us-news',
#    'sectionName': 'US news',
#    'webPublicationDate': '2020-11-09T11:16:48Z',
#    'webTitle': 'Biden gets down to work, but Trump still not budging | First Thing',
#    'webUrl': 'https://www.theguardian.com/us-news/2020/nov/09/first-thing-biden-gets-down-to-work-but-trump-still-not-budging',
#    'apiUrl': 'https://content.guardianapis.com/us-news/2020/nov/09/first-thing-biden-gets-down-to-work-but-trump-still-not-budging',
#    'isHosted': False,
#    'pillarId': 'pillar/news',
#    'pillarName': 'News'}]}

# %%
pages = biden["pages"]
pages
# Out:
# 10

# %%
pageSize = biden["pageSize"]
pageSize
# Out:
# 50

# %%
# Loop over remaining pages.
import time

results = biden["results"]
for p in range(2, pages + 1):
    results += get_articles("biden", p)["results"]
    time.sleep(0.1) # 3 seconds

# %%
results
# Out:
# [{'id': 'australia-news/2020/nov/05/biden-edges-closer-to-victory',
#   'type': 'article',
#   'sectionId': 'australia-news',
#   'sectionName': 'Australia news',
#   'webPublicationDate': '2020-11-05T05:38:22Z',
#   'webTitle': 'US election briefing for Australia: Biden edges closer to victory',
#   'webUrl': 'https://www.theguardian.com/australia-news/2020/nov/05/biden-edges-closer-to-victory',
#   'apiUrl': 'https://content.guardianapis.com/australia-news/2020/nov/05/biden-edges-closer-to-victory',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'politics/2020/nov/10/johnsons-biden-win-tweet-contains-hidden-trump-congratulations',
#   'type': 'article',
#   'sectionId': 'politics',
#   'sectionName': 'Politics',
#   'webPublicationDate': '2020-11-10T13:19:16Z',
#   'webTitle': "Johnson's Biden win tweet contains hidden Trump congratulations",
#   'webUrl': 'https://www.theguardian.com/politics/2020/nov/10/johnsons-biden-win-tweet-contains-hidden-trump-congratulations',
#   'apiUrl': 'https://content.guardianapis.com/politics/2020/nov/10/johnsons-biden-win-tweet-contains-hidden-trump-congratulations',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'us-news/live/2020/nov/07/us-election-joe-biden-wins-presidency-donald-trump-kamala-harris-2020-latest-updates',
#   'type': 'liveblog',
#   'sectionId': 'us-news',
#   'sectionName': 'US news',
#   'webPublicationDate': '2020-11-08T10:04:24Z',
#   'webTitle': 'Biden addresses Americans after victory – as it happened',
#   'webUrl': 'https://www.theguardian.com/us-news/live/2020/nov/07/us-election-joe-biden-wins-presidency-donald-trump-kamala-harris-2020-latest-updates',
#   'apiUrl': 'https://content.guardianapis.com/us-news/live/2020/nov/07/us-election-joe-biden-wins-presidency-donald-trump-kamala-harris-2020-latest-updates',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'us-news/2020/nov/08/donald-trump-concede-legal-challenge-republicans-joe-biden-golf',
#   'type': 'article',
#   'sectionId': 'us-news',
#   'sectionName': 'US news',
#   'webPublicationDate': '2020-11-08T19:39:23Z',
#   'webTitle': 'Republicans back Trump challenge to Biden election victory',
#   'webUrl': 'https://www.theguardian.com/us-news/2020/nov/08/donald-trump-concede-legal-challenge-republicans-joe-biden-golf',
#   'apiUrl': 'https://content.guardianapis.com/us-news/2020/nov/08/donald-trump-concede-legal-challenge-republicans-joe-biden-golf',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'us-news/2020/nov/07/joe-biden-disunited-states-of-america',
#   'type': 'article',
#   'sectionId': 'us-news',
#   'sectionName': 'US news',
#   'webPublicationDate': '2020-11-07T10:00:07Z',
#   'webTitle': 'Joe Biden poised to inherit Disunited States of America',
#   'webUrl': 'https://www.theguardian.com/us-news/2020/nov/07/joe-biden-disunited-states-of-america',
#   'apiUrl': 'https://content.guardianapis.com/us-news/2020/nov/07/joe-biden-disunited-states-of-america',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'business/2020/nov/05/global-stock-markets-climb-on-prospect-of-biden-presidency',
#   'type': 'article',
#   'sectionId': 'business',
#   'sectionName': 'Business',
#   'webPublicationDate': '2020-11-05T05:57:36Z',
#   'webTitle': 'Global stock markets climb on prospect of Biden presidency',
#   'webUrl': 'https://www.theguardian.com/business/2020/nov/05/global-stock-markets-climb-on-prospect-of-biden-presidency',
#   'apiUrl': 'https://content.guardianapis.com/business/2020/nov/05/global-stock-markets-climb-on-prospect-of-biden-presidency',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'world/2020/nov/09/monday-briefing-biden-to-make-covid-top-priority',
#   'type': 'article',
#   'sectionId': 'world',
#   'sectionName': 'World news',
#   'webPublicationDate': '2020-11-09T06:24:26Z',
#   'webTitle': 'Monday briefing: Biden to make Covid top priority',
#   'webUrl': 'https://www.theguardian.com/world/2020/nov/09/monday-briefing-biden-to-make-covid-top-priority',
#   'apiUrl': 'https://content.guardianapis.com/world/2020/nov/09/monday-briefing-biden-to-make-covid-top-priority',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'us-news/2020/nov/08/joe-biden-trauma-and-triumph-the-10-moments-that-made-him',
#   'type': 'article',
#   'sectionId': 'us-news',
#   'sectionName': 'US news',
#   'webPublicationDate': '2020-11-08T12:33:41Z',
#   'webTitle': 'Trauma and triumph: the 10 moments that made Joe Biden',
#   'webUrl': 'https://www.theguardian.com/us-news/2020/nov/08/joe-biden-trauma-and-triumph-the-10-moments-that-made-him',
#   'apiUrl': 'https://content.guardianapis.com/us-news/2020/nov/08/joe-biden-trauma-and-triumph-the-10-moments-that-made-him',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'us-news/2020/nov/08/joe-biden-paris-climate-goals-0-1c',
#   'type': 'article',
#   'sectionId': 'environment',
#   'sectionName': 'Environment',
#   'webPublicationDate': '2020-11-08T11:32:04Z',
#   'webTitle': "Joe Biden could bring Paris climate goals 'within striking distance'",
#   'webUrl': 'https://www.theguardian.com/us-news/2020/nov/08/joe-biden-paris-climate-goals-0-1c',
#   'apiUrl': 'https://content.guardianapis.com/us-news/2020/nov/08/joe-biden-paris-climate-goals-0-1c',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'us-news/2020/nov/05/fox-draws-trump-campaigns-ire-after-early-call-of-arizona-for-biden',
#   'type': 'article',
#   'sectionId': 'us-news',
#   'sectionName': 'US news',
#   'webPublicationDate': '2020-11-05T14:07:08Z',
#   'webTitle': "Fox draws Trump campaign's ire after calling Arizona for Biden",
#   'webUrl': 'https://www.theguardian.com/us-news/2020/nov/05/fox-draws-trump-campaigns-ire-after-early-call-of-arizona-for-biden',
#   'apiUrl': 'https://content.guardianapis.com/us-news/2020/nov/05/fox-draws-trump-campaigns-ire-after-early-call-of-arizona-for-biden',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'us-news/2020/nov/04/trump-wins-florida-2020-election-biden',
#   'type': 'article',
#   'sectionId': 'us-news',
#   'sectionName': 'US news',
#   'webPublicationDate': '2020-11-04T06:50:49Z',
#   'webTitle': 'Trump wins swing state Florida in setback for Biden campaign',
#   'webUrl': 'https://www.theguardian.com/us-news/2020/nov/04/trump-wins-florida-2020-election-biden',
#   'apiUrl': 'https://content.guardianapis.com/us-news/2020/nov/04/trump-wins-florida-2020-election-biden',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'music/2020/nov/03/lady-gaga-attacks-donald-trump-at-joe-biden-rally',
#   'type': 'article',
#   'sectionId': 'music',
#   'sectionName': 'Music',
#   'webPublicationDate': '2020-11-03T09:07:48Z',
#   'webTitle': "Lady Gaga attacks Trump's 'grab' remarks at Joe Biden rally",
#   'webUrl': 'https://www.theguardian.com/music/2020/nov/03/lady-gaga-attacks-donald-trump-at-joe-biden-rally',
#   'apiUrl': 'https://content.guardianapis.com/music/2020/nov/03/lady-gaga-attacks-donald-trump-at-joe-biden-rally',
#   'isHosted': False,
#   'pillarId': 'pillar/arts',
#   'pillarName': 'Arts'},
#  {'id': 'tv-and-radio/2020/nov/03/tv-tonight-the-moment-of-truth-for-trump-and-biden',
#   'type': 'article',
#   'sectionId': 'tv-and-radio',
#   'sectionName': 'Television & radio',
#   'webPublicationDate': '2020-11-03T06:00:49Z',
#   'webTitle': 'TV tonight: the moment of truth  for Trump and Biden',
#   'webUrl': 'https://www.theguardian.com/tv-and-radio/2020/nov/03/tv-tonight-the-moment-of-truth-for-trump-and-biden',
#   'apiUrl': 'https://content.guardianapis.com/tv-and-radio/2020/nov/03/tv-tonight-the-moment-of-truth-for-trump-and-biden',
#   'isHosted': False,
#   'pillarId': 'pillar/arts',
#   'pillarName': 'Arts'},
#  {'id': 'us-news/ng-interactive/2020/nov/07/how-did-joe-biden-win-presidency-visual-guide',
#   'type': 'interactive',
#   'sectionId': 'us-news',
#   'sectionName': 'US news',
#   'webPublicationDate': '2020-11-09T10:35:17Z',
#   'webTitle': 'How Joe Biden won the presidency – a visual guide',
#   'webUrl': 'https://www.theguardian.com/us-news/ng-interactive/2020/nov/07/how-did-joe-biden-win-presidency-visual-guide',
#   'apiUrl': 'https://content.guardianapis.com/us-news/ng-interactive/2020/nov/07/how-did-joe-biden-win-presidency-visual-guide',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'commentisfree/2020/nov/09/the-guardian-view-on-johnsons-biden-problem-not-going-away',
#   'type': 'article',
#   'sectionId': 'commentisfree',
#   'sectionName': 'Opinion',
#   'webPublicationDate': '2020-11-09T19:25:48Z',
#   'webTitle': "The Guardian view on Johnson's Biden problem: not going away | Editorial",
#   'webUrl': 'https://www.theguardian.com/commentisfree/2020/nov/09/the-guardian-view-on-johnsons-biden-problem-not-going-away',
#   'apiUrl': 'https://content.guardianapis.com/commentisfree/2020/nov/09/the-guardian-view-on-johnsons-biden-problem-not-going-away',
#   'isHosted': False,
#   'pillarId': 'pillar/opinion',
#   'pillarName': 'Opinion'},
#  {'id': 'business/2020/nov/09/biden-win-boosts-global-stock-markets-as-japanese-shares-soar-to-29-year-high',
#   'type': 'article',
#   'sectionId': 'business',
#   'sectionName': 'Business',
#   'webPublicationDate': '2020-11-09T10:24:55Z',
#   'webTitle': 'Biden win boosts global stock markets as FTSE 100 surges',
#   'webUrl': 'https://www.theguardian.com/business/2020/nov/09/biden-win-boosts-global-stock-markets-as-japanese-shares-soar-to-29-year-high',
#   'apiUrl': 'https://content.guardianapis.com/business/2020/nov/09/biden-win-boosts-global-stock-markets-as-japanese-shares-soar-to-29-year-high',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'politics/2020/nov/09/uk-risks-becoming-international-pariah-by-rewriting-brexit-bill',
#   'type': 'article',
#   'sectionId': 'politics',
#   'sectionName': 'Politics',
#   'webPublicationDate': '2020-11-09T09:15:47Z',
#   'webTitle': "Brexit: UK risks being 'international pariah' under Biden, says Labour",
#   'webUrl': 'https://www.theguardian.com/politics/2020/nov/09/uk-risks-becoming-international-pariah-by-rewriting-brexit-bill',
#   'apiUrl': 'https://content.guardianapis.com/politics/2020/nov/09/uk-risks-becoming-international-pariah-by-rewriting-brexit-bill',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'us-news/2020/nov/10/joe-biden-donald-trump-never-see-again-valerie-biden-owens-interview-axios',
#   'type': 'article',
#   'sectionId': 'us-news',
#   'sectionName': 'US news',
#   'webPublicationDate': '2020-11-10T14:13:51Z',
#   'webTitle': 'Biden ‘never going to see Trump again’ after inauguration, says sister',
#   'webUrl': 'https://www.theguardian.com/us-news/2020/nov/10/joe-biden-donald-trump-never-see-again-valerie-biden-owens-interview-axios',
#   'apiUrl': 'https://content.guardianapis.com/us-news/2020/nov/10/joe-biden-donald-trump-never-see-again-valerie-biden-owens-interview-axios',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'us-news/2020/nov/03/biden-sweeps-board-in-tiny-new-hampshire-village-dixville-notch',
#   'type': 'article',
#   'sectionId': 'us-news',
#   'sectionName': 'US news',
#   'webPublicationDate': '2020-11-03T12:56:42Z',
#   'webTitle': 'Biden sweeps board in tiny New Hampshire village Dixville Notch',
#   'webUrl': 'https://www.theguardian.com/us-news/2020/nov/03/biden-sweeps-board-in-tiny-new-hampshire-village-dixville-notch',
#   'apiUrl': 'https://content.guardianapis.com/us-news/2020/nov/03/biden-sweeps-board-in-tiny-new-hampshire-village-dixville-notch',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'us-news/live/2020/nov/05/us-election-joe-biden-donald-trump-result-latest-who-is-winning-live-2020-updates',
#   'type': 'liveblog',
#   'sectionId': 'us-news',
#   'sectionName': 'US news',
#   'webPublicationDate': '2020-11-06T19:33:10Z',
#   'webTitle': 'Growing lead for Biden in Nevada and Pennsylvania\xa0– as it happened',
#   'webUrl': 'https://www.theguardian.com/us-news/live/2020/nov/05/us-election-joe-biden-donald-trump-result-latest-who-is-winning-live-2020-updates',
#   'apiUrl': 'https://content.guardianapis.com/us-news/live/2020/nov/05/us-election-joe-biden-donald-trump-result-latest-who-is-winning-live-2020-updates',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'us-news/2020/nov/04/us-election-takeaways-biden-trump-polls',
#   'type': 'article',
#   'sectionId': 'us-news',
#   'sectionName': 'US news',
#   'webPublicationDate': '2020-11-04T17:59:06Z',
#   'webTitle': 'Six key election takeaways – about Biden, Trump and those misleading polls',
#   'webUrl': 'https://www.theguardian.com/us-news/2020/nov/04/us-election-takeaways-biden-trump-polls',
#   'apiUrl': 'https://content.guardianapis.com/us-news/2020/nov/04/us-election-takeaways-biden-trump-polls',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'world/2020/nov/04/wednesday-briefing-biden-i-believe-we-are-on-track-to-win',
#   'type': 'article',
#   'sectionId': 'world',
#   'sectionName': 'World news',
#   'webPublicationDate': '2020-11-04T06:30:25Z',
#   'webTitle': "Wednesday briefing: Biden – 'I believe we are on track to win'",
#   'webUrl': 'https://www.theguardian.com/world/2020/nov/04/wednesday-briefing-biden-i-believe-we-are-on-track-to-win',
#   'apiUrl': 'https://content.guardianapis.com/world/2020/nov/04/wednesday-briefing-biden-i-believe-we-are-on-track-to-win',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'us-news/2020/nov/10/joe-biden-trump-embarrassment-refusal-to-concede-election',
#   'type': 'article',
#   'sectionId': 'us-news',
#   'sectionName': 'US news',
#   'webPublicationDate': '2020-11-10T22:45:45Z',
#   'webTitle': "'An embarrassment': Joe Biden criticizes Trump's refusal to concede election",
#   'webUrl': 'https://www.theguardian.com/us-news/2020/nov/10/joe-biden-trump-embarrassment-refusal-to-concede-election',
#   'apiUrl': 'https://content.guardianapis.com/us-news/2020/nov/10/joe-biden-trump-embarrassment-refusal-to-concede-election',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'us-news/2020/nov/08/russia-and-china-silence-speaks-volumes-as-leaders-congratulate-biden',
#   'type': 'article',
#   'sectionId': 'us-news',
#   'sectionName': 'US news',
#   'webPublicationDate': '2020-11-08T17:46:38Z',
#   'webTitle': 'Russia and China silence speaks volumes as leaders congratulate Biden',
#   'webUrl': 'https://www.theguardian.com/us-news/2020/nov/08/russia-and-china-silence-speaks-volumes-as-leaders-congratulate-biden',
#   'apiUrl': 'https://content.guardianapis.com/us-news/2020/nov/08/russia-and-china-silence-speaks-volumes-as-leaders-congratulate-biden',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'commentisfree/2020/nov/08/its-president-biden-what-a-relief-for-the-whole-world',
#   'type': 'article',
#   'sectionId': 'commentisfree',
#   'sectionName': 'Opinion',
#   'webPublicationDate': '2020-11-07T20:23:07Z',
#   'webTitle': "It's PRESIDENT BIDEN! What a 'relief' for the whole world! | First Dog on the Moon",
#   'webUrl': 'https://www.theguardian.com/commentisfree/2020/nov/08/its-president-biden-what-a-relief-for-the-whole-world',
#   'apiUrl': 'https://content.guardianapis.com/commentisfree/2020/nov/08/its-president-biden-what-a-relief-for-the-whole-world',
#   'isHosted': False,
#   'pillarId': 'pillar/opinion',
#   'pillarName': 'Opinion'},
#  {'id': 'world/2020/nov/05/thursday-briefing-biden-with-one-hand-on-the-prize',
#   'type': 'article',
#   'sectionId': 'world',
#   'sectionName': 'World news',
#   'webPublicationDate': '2020-11-05T06:32:05Z',
#   'webTitle': 'Thursday briefing: Joe Biden with one hand on the prize',
#   'webUrl': 'https://www.theguardian.com/world/2020/nov/05/thursday-briefing-biden-with-one-hand-on-the-prize',
#   'apiUrl': 'https://content.guardianapis.com/world/2020/nov/05/thursday-briefing-biden-with-one-hand-on-the-prize',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'business/2020/nov/03/stock-markets-soar-as-city-traders-anticipate-joe-biden-win',
#   'type': 'article',
#   'sectionId': 'business',
#   'sectionName': 'Business',
#   'webPublicationDate': '2020-11-03T13:17:26Z',
#   'webTitle': 'Stock markets soar as City traders anticipate Joe Biden win',
#   'webUrl': 'https://www.theguardian.com/business/2020/nov/03/stock-markets-soar-as-city-traders-anticipate-joe-biden-win',
#   'apiUrl': 'https://content.guardianapis.com/business/2020/nov/03/stock-markets-soar-as-city-traders-anticipate-joe-biden-win',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'world/2020/nov/02/monday-briefing-biden-v-trump-final-countdown-to-us-election',
#   'type': 'article',
#   'sectionId': 'world',
#   'sectionName': 'World news',
#   'webPublicationDate': '2020-11-02T06:31:39Z',
#   'webTitle': 'Monday briefing: Biden v Trump – final countdown to US election',
#   'webUrl': 'https://www.theguardian.com/world/2020/nov/02/monday-briefing-biden-v-trump-final-countdown-to-us-election',
#   'apiUrl': 'https://content.guardianapis.com/world/2020/nov/02/monday-briefing-biden-v-trump-final-countdown-to-us-election',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'politics/2020/nov/10/boris-johnson-phones-to-congratulate-joe-biden-and-discuss-close-relationship',
#   'type': 'article',
#   'sectionId': 'politics',
#   'sectionName': 'Politics',
#   'webPublicationDate': '2020-11-10T21:17:18Z',
#   'webTitle': "Boris Johnson phones to congratulate Joe Biden and discuss 'close' relationship",
#   'webUrl': 'https://www.theguardian.com/politics/2020/nov/10/boris-johnson-phones-to-congratulate-joe-biden-and-discuss-close-relationship',
#   'apiUrl': 'https://content.guardianapis.com/politics/2020/nov/10/boris-johnson-phones-to-congratulate-joe-biden-and-discuss-close-relationship',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'society/2020/nov/10/reproductive-health-ngos-abortion-pin-hopes-on-biden-reversing-global-gag-rule',
#   'type': 'article',
#   'sectionId': 'society',
#   'sectionName': 'Society',
#   'webPublicationDate': '2020-11-10T11:28:23Z',
#   'webTitle': 'Reproductive health NGOs pin hopes on Biden reversing ‘global gag rule’',
#   'webUrl': 'https://www.theguardian.com/society/2020/nov/10/reproductive-health-ngos-abortion-pin-hopes-on-biden-reversing-global-gag-rule',
#   'apiUrl': 'https://content.guardianapis.com/society/2020/nov/10/reproductive-health-ngos-abortion-pin-hopes-on-biden-reversing-global-gag-rule',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'australia-news/2020/nov/09/biden-era-begins-but-trump-fights-on-in-his-own-world',
#   'type': 'article',
#   'sectionId': 'australia-news',
#   'sectionName': 'Australia news',
#   'webPublicationDate': '2020-11-09T05:35:34Z',
#   'webTitle': 'US election briefing for Australia: Biden era begins, but Trump fights on in his own world',
#   'webUrl': 'https://www.theguardian.com/australia-news/2020/nov/09/biden-era-begins-but-trump-fights-on-in-his-own-world',
#   'apiUrl': 'https://content.guardianapis.com/australia-news/2020/nov/09/biden-era-begins-but-trump-fights-on-in-his-own-world',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'commentisfree/2020/nov/08/joe-biden-donald-trump-election-healing-robert-reich',
#   'type': 'article',
#   'sectionId': 'commentisfree',
#   'sectionName': 'Opinion',
#   'webPublicationDate': '2020-11-08T06:00:31Z',
#   'webTitle': 'How can Biden heal America when Trump doesn’t want it healed? | Robert Reich',
#   'webUrl': 'https://www.theguardian.com/commentisfree/2020/nov/08/joe-biden-donald-trump-election-healing-robert-reich',
#   'apiUrl': 'https://content.guardianapis.com/commentisfree/2020/nov/08/joe-biden-donald-trump-election-healing-robert-reich',
#   'isHosted': False,
#   'pillarId': 'pillar/opinion',
#   'pillarName': 'Opinion'},
#  {'id': 'us-news/2020/nov/07/trump-supporters-protest-pennsylvania-michigan',
#   'type': 'article',
#   'sectionId': 'us-news',
#   'sectionName': 'US news',
#   'webPublicationDate': '2020-11-08T03:27:53Z',
#   'webTitle': "'It's not over': Trump supporters protest Biden victory in swing states",
#   'webUrl': 'https://www.theguardian.com/us-news/2020/nov/07/trump-supporters-protest-pennsylvania-michigan',
#   'apiUrl': 'https://content.guardianapis.com/us-news/2020/nov/07/trump-supporters-protest-pennsylvania-michigan',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'us-news/2020/nov/07/ever-resilient-president-joe-biden-finally-grasps-chance-lead-america',
#   'type': 'article',
#   'sectionId': 'us-news',
#   'sectionName': 'US news',
#   'webPublicationDate': '2020-11-07T16:32:29Z',
#   'webTitle': 'Ever resilient, Joe Biden finally grasps his chance to lead America',
#   'webUrl': 'https://www.theguardian.com/us-news/2020/nov/07/ever-resilient-president-joe-biden-finally-grasps-chance-lead-america',
#   'apiUrl': 'https://content.guardianapis.com/us-news/2020/nov/07/ever-resilient-president-joe-biden-finally-grasps-chance-lead-america',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'us-news/2020/nov/08/joe-biden-coronavirus-taskforce',
#   'type': 'article',
#   'sectionId': 'us-news',
#   'sectionName': 'US news',
#   'webPublicationDate': '2020-11-08T16:22:16Z',
#   'webTitle': 'US posts fourth consecutive daily Covid record as Joe Biden prepares taskforce',
#   'webUrl': 'https://www.theguardian.com/us-news/2020/nov/08/joe-biden-coronavirus-taskforce',
#   'apiUrl': 'https://content.guardianapis.com/us-news/2020/nov/08/joe-biden-coronavirus-taskforce',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'us-news/2020/nov/08/biden-transition-team-plans-executive-orders-covid-taskforce',
#   'type': 'article',
#   'sectionId': 'us-news',
#   'sectionName': 'US news',
#   'webPublicationDate': '2020-11-08T15:07:18Z',
#   'webTitle': "Joe Biden faces rocky transition as work of undoing Trump's damage begins",
#   'webUrl': 'https://www.theguardian.com/us-news/2020/nov/08/biden-transition-team-plans-executive-orders-covid-taskforce',
#   'apiUrl': 'https://content.guardianapis.com/us-news/2020/nov/08/biden-transition-team-plans-executive-orders-covid-taskforce',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'politics/2020/nov/08/three-times-as-many-british-voters-favour-joe-biden-than-donald-trump',
#   'type': 'article',
#   'sectionId': 'politics',
#   'sectionName': 'Politics',
#   'webPublicationDate': '2020-11-08T06:20:31Z',
#   'webTitle': 'Three times as many British voters favour Joe Biden than Donald Trump',
#   'webUrl': 'https://www.theguardian.com/politics/2020/nov/08/three-times-as-many-british-voters-favour-joe-biden-than-donald-trump',
#   'apiUrl': 'https://content.guardianapis.com/politics/2020/nov/08/three-times-as-many-british-voters-favour-joe-biden-than-donald-trump',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'us-news/2020/nov/07/trump-fox-news-joe-biden-rightwing-media',
#   'type': 'article',
#   'sectionId': 'us-news',
#   'sectionName': 'US news',
#   'webPublicationDate': '2020-11-07T23:28:02Z',
#   'webTitle': 'Loyal Trump outlets cry betrayal after Fox News calls election for Biden',
#   'webUrl': 'https://www.theguardian.com/us-news/2020/nov/07/trump-fox-news-joe-biden-rightwing-media',
#   'apiUrl': 'https://content.guardianapis.com/us-news/2020/nov/07/trump-fox-news-joe-biden-rightwing-media',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'us-news/2020/nov/07/donald-trump-golf-course-joe-biden-election',
#   'type': 'article',
#   'sectionId': 'us-news',
#   'sectionName': 'US news',
#   'webPublicationDate': '2020-11-07T15:52:08Z',
#   'webTitle': 'Trump heads for golf club – again – before defeat by Biden is called',
#   'webUrl': 'https://www.theguardian.com/us-news/2020/nov/07/donald-trump-golf-course-joe-biden-election',
#   'apiUrl': 'https://content.guardianapis.com/us-news/2020/nov/07/donald-trump-golf-course-joe-biden-election',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'us-news/2020/nov/02/trump-biden-supporters-campaign-bus',
#   'type': 'article',
#   'sectionId': 'us-news',
#   'sectionName': 'US news',
#   'webPublicationDate': '2020-11-02T16:53:34Z',
#   'webTitle': "Trump says supporters who harassed Biden campaign bus 'did nothing wrong'",
#   'webUrl': 'https://www.theguardian.com/us-news/2020/nov/02/trump-biden-supporters-campaign-bus',
#   'apiUrl': 'https://content.guardianapis.com/us-news/2020/nov/02/trump-biden-supporters-campaign-bus',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'us-news/live/2020/nov/01/us-election-2020-donald-trump-joe-biden-mike-pence-kamala-harris-coronavirus-covid-19-live-updates',
#   'type': 'liveblog',
#   'sectionId': 'us-news',
#   'sectionName': 'US news',
#   'webPublicationDate': '2020-11-02T06:01:06Z',
#   'webTitle': 'FBI confirms it is investigating Biden bus incident – as it happened',
#   'webUrl': 'https://www.theguardian.com/us-news/live/2020/nov/01/us-election-2020-donald-trump-joe-biden-mike-pence-kamala-harris-coronavirus-covid-19-live-updates',
#   'apiUrl': 'https://content.guardianapis.com/us-news/live/2020/nov/01/us-election-2020-donald-trump-joe-biden-mike-pence-kamala-harris-coronavirus-covid-19-live-updates',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'us-news/2020/nov/05/biden-trump-us-election-2020-votes-count',
#   'type': 'article',
#   'sectionId': 'us-news',
#   'sectionName': 'US news',
#   'webPublicationDate': '2020-11-06T10:13:03Z',
#   'webTitle': "Trump repeats false claim of election win as Biden calls for 'patience'",
#   'webUrl': 'https://www.theguardian.com/us-news/2020/nov/05/biden-trump-us-election-2020-votes-count',
#   'apiUrl': 'https://content.guardianapis.com/us-news/2020/nov/05/biden-trump-us-election-2020-votes-count',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'us-news/2020/nov/03/joe-biden-campaign-election-night-event',
#   'type': 'article',
#   'sectionId': 'us-news',
#   'sectionName': 'US news',
#   'webPublicationDate': '2020-11-04T16:10:43Z',
#   'webTitle': "'We're on track to win': Biden expresses optimism as vote count continues",
#   'webUrl': 'https://www.theguardian.com/us-news/2020/nov/03/joe-biden-campaign-election-night-event',
#   'apiUrl': 'https://content.guardianapis.com/us-news/2020/nov/03/joe-biden-campaign-election-night-event',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'us-news/ng-interactive/2020/oct/30/build-your-own-us-election-result-plot-a-win-for-biden-or-trump',
#   'type': 'interactive',
#   'sectionId': 'us-news',
#   'sectionName': 'US news',
#   'webPublicationDate': '2020-11-03T16:41:53Z',
#   'webTitle': 'Build your own US election result: plot a Biden or Trump win',
#   'webUrl': 'https://www.theguardian.com/us-news/ng-interactive/2020/oct/30/build-your-own-us-election-result-plot-a-win-for-biden-or-trump',
#   'apiUrl': 'https://content.guardianapis.com/us-news/ng-interactive/2020/oct/30/build-your-own-us-election-result-plot-a-win-for-biden-or-trump',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'world/2020/nov/01/democracy-fascism-global-trump-biden-election',
#   'type': 'article',
#   'sectionId': 'world',
#   'sectionName': 'World news',
#   'webPublicationDate': '2020-11-01T16:00:24Z',
#   'webTitle': 'Scholars warn of collapse of democracy as Trump v Biden election looms',
#   'webUrl': 'https://www.theguardian.com/world/2020/nov/01/democracy-fascism-global-trump-biden-election',
#   'apiUrl': 'https://content.guardianapis.com/world/2020/nov/01/democracy-fascism-global-trump-biden-election',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'world/2020/nov/09/his-speech-was-perfect-china-celebrates-biden-win-amid-hopes-for-warmer-ties',
#   'type': 'article',
#   'sectionId': 'world',
#   'sectionName': 'World news',
#   'webPublicationDate': '2020-11-09T14:02:07Z',
#   'webTitle': "'His speech was perfect': Chinese social media users celebrate Biden win",
#   'webUrl': 'https://www.theguardian.com/world/2020/nov/09/his-speech-was-perfect-china-celebrates-biden-win-amid-hopes-for-warmer-ties',
#   'apiUrl': 'https://content.guardianapis.com/world/2020/nov/09/his-speech-was-perfect-china-celebrates-biden-win-amid-hopes-for-warmer-ties',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'politics/2020/nov/08/dominic-raab-joe-biden-no-deal-brexit',
#   'type': 'article',
#   'sectionId': 'politics',
#   'sectionName': 'Politics',
#   'webPublicationDate': '2020-11-08T13:54:39Z',
#   'webTitle': 'Johnson risks rift with Biden by pressing ahead with Brexit bill',
#   'webUrl': 'https://www.theguardian.com/politics/2020/nov/08/dominic-raab-joe-biden-no-deal-brexit',
#   'apiUrl': 'https://content.guardianapis.com/politics/2020/nov/08/dominic-raab-joe-biden-no-deal-brexit',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'us-news/2020/nov/05/florida-latino-voters-joe-biden-donald-trump',
#   'type': 'article',
#   'sectionId': 'us-news',
#   'sectionName': 'US news',
#   'webPublicationDate': '2020-11-05T19:57:31Z',
#   'webTitle': "'Republicans built the base': how Joe Biden lost Florida's Latino voters",
#   'webUrl': 'https://www.theguardian.com/us-news/2020/nov/05/florida-latino-voters-joe-biden-donald-trump',
#   'apiUrl': 'https://content.guardianapis.com/us-news/2020/nov/05/florida-latino-voters-joe-biden-donald-trump',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'us-news/2020/nov/04/democrats-senate-house-down-ballot-races-biden',
#   'type': 'article',
#   'sectionId': 'us-news',
#   'sectionName': 'US news',
#   'webPublicationDate': '2020-11-04T22:12:01Z',
#   'webTitle': 'Joe Biden bullish but down-ballot races deliver disappointment for Democrats',
#   'webUrl': 'https://www.theguardian.com/us-news/2020/nov/04/democrats-senate-house-down-ballot-races-biden',
#   'apiUrl': 'https://content.guardianapis.com/us-news/2020/nov/04/democrats-senate-house-down-ballot-races-biden',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'us-news/2020/nov/09/first-thing-biden-gets-down-to-work-but-trump-still-not-budging',
#   'type': 'article',
#   'sectionId': 'us-news',
#   'sectionName': 'US news',
#   'webPublicationDate': '2020-11-09T11:16:48Z',
#   'webTitle': 'Biden gets down to work, but Trump still not budging | First Thing',
#   'webUrl': 'https://www.theguardian.com/us-news/2020/nov/09/first-thing-biden-gets-down-to-work-but-trump-still-not-budging',
#   'apiUrl': 'https://content.guardianapis.com/us-news/2020/nov/09/first-thing-biden-gets-down-to-work-but-trump-still-not-budging',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'us-news/2020/nov/09/first-thing-biden-gets-down-to-work-but-trump-still-not-budging',
#   'type': 'article',
#   'sectionId': 'us-news',
#   'sectionName': 'US news',
#   'webPublicationDate': '2020-11-09T11:16:48Z',
#   'webTitle': 'Biden gets down to work, but Trump still not budging | First Thing',
#   'webUrl': 'https://www.theguardian.com/us-news/2020/nov/09/first-thing-biden-gets-down-to-work-but-trump-still-not-budging',
#   'apiUrl': 'https://content.guardianapis.com/us-news/2020/nov/09/first-thing-biden-gets-down-to-work-but-trump-still-not-budging',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'world/2020/nov/09/pacific-nations-herald-biden-presidency-amid-hope-for-action-on-climate-emergency',
#   'type': 'article',
#   'sectionId': 'world',
#   'sectionName': 'World news',
#   'webPublicationDate': '2020-11-09T02:50:57Z',
#   'webTitle': 'Pacific nations herald Biden presidency amid hope for action on climate emergency',
#   'webUrl': 'https://www.theguardian.com/world/2020/nov/09/pacific-nations-herald-biden-presidency-amid-hope-for-action-on-climate-emergency',
#   'apiUrl': 'https://content.guardianapis.com/world/2020/nov/09/pacific-nations-herald-biden-presidency-amid-hope-for-action-on-climate-emergency',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'australia-news/2020/nov/09/morning-mail-trump-refuses-to-concede-as-biden-declared-us-president-elect',
#   'type': 'article',
#   'sectionId': 'australia-news',
#   'sectionName': 'Australia news',
#   'webPublicationDate': '2020-11-08T20:09:01Z',
#   'webTitle': 'Morning mail: Trump refuses to concede as Biden declared US president-elect',
#   'webUrl': 'https://www.theguardian.com/australia-news/2020/nov/09/morning-mail-trump-refuses-to-concede-as-biden-declared-us-president-elect',
#   'apiUrl': 'https://content.guardianapis.com/australia-news/2020/nov/09/morning-mail-trump-refuses-to-concede-as-biden-declared-us-president-elect',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'us-news/2020/nov/07/biden-styled-himself-as-the-antithesis-to-bare-knuckled-trumpism-and-won',
#   'type': 'article',
#   'sectionId': 'us-news',
#   'sectionName': 'US news',
#   'webPublicationDate': '2020-11-07T16:33:51Z',
#   'webTitle': 'Biden styled himself as the antithesis to bare-knuckled Trumpism – and won',
#   'webUrl': 'https://www.theguardian.com/us-news/2020/nov/07/biden-styled-himself-as-the-antithesis-to-bare-knuckled-trumpism-and-won',
#   'apiUrl': 'https://content.guardianapis.com/us-news/2020/nov/07/biden-styled-himself-as-the-antithesis-to-bare-knuckled-trumpism-and-won',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'us-news/2020/nov/07/joe-biden-wins-us-election-donald-trump-loses-final-result-2020',
#   'type': 'article',
#   'sectionId': 'us-news',
#   'sectionName': 'US news',
#   'webPublicationDate': '2020-11-07T16:32:28Z',
#   'webTitle': 'Joe Biden wins US election after four tumultuous years of Trump presidency',
#   'webUrl': 'https://www.theguardian.com/us-news/2020/nov/07/joe-biden-wins-us-election-donald-trump-loses-final-result-2020',
#   'apiUrl': 'https://content.guardianapis.com/us-news/2020/nov/07/joe-biden-wins-us-election-donald-trump-loses-final-result-2020',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'us-news/2020/nov/08/joe-biden-president-elect-donald-trump-concede-republicans-democrats-aoc-ocasio-cortez',
#   'type': 'article',
#   'sectionId': 'us-news',
#   'sectionName': 'US news',
#   'webPublicationDate': '2020-11-09T07:37:29Z',
#   'webTitle': 'Joe Biden gets to work as president-elect while Trump refuses to concede',
#   'webUrl': 'https://www.theguardian.com/us-news/2020/nov/08/joe-biden-president-elect-donald-trump-concede-republicans-democrats-aoc-ocasio-cortez',
#   'apiUrl': 'https://content.guardianapis.com/us-news/2020/nov/08/joe-biden-president-elect-donald-trump-concede-republicans-democrats-aoc-ocasio-cortez',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'us-news/2020/nov/04/paths-to-us-election-victory-what-trump-and-biden-need-to-win',
#   'type': 'article',
#   'sectionId': 'us-news',
#   'sectionName': 'US news',
#   'webPublicationDate': '2020-11-06T08:31:19Z',
#   'webTitle': 'Paths to US election victory: what Trump and Biden need to win',
#   'webUrl': 'https://www.theguardian.com/us-news/2020/nov/04/paths-to-us-election-victory-what-trump-and-biden-need-to-win',
#   'apiUrl': 'https://content.guardianapis.com/us-news/2020/nov/04/paths-to-us-election-victory-what-trump-and-biden-need-to-win',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'environment/2020/nov/08/australia-warned-it-could-be-isolated-over-climate-inaction-after-joe-biden-victory',
#   'type': 'article',
#   'sectionId': 'environment',
#   'sectionName': 'Environment',
#   'webPublicationDate': '2020-11-07T20:29:32Z',
#   'webTitle': 'Australia warned it could be isolated over climate inaction\xa0after Joe Biden victory',
#   'webUrl': 'https://www.theguardian.com/environment/2020/nov/08/australia-warned-it-could-be-isolated-over-climate-inaction-after-joe-biden-victory',
#   'apiUrl': 'https://content.guardianapis.com/environment/2020/nov/08/australia-warned-it-could-be-isolated-over-climate-inaction-after-joe-biden-victory',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'business/commentisfree/2020/nov/08/biden-lost-florida-but-he-helped-raise-the-minimum-wage-there-policy-matters',
#   'type': 'article',
#   'sectionId': 'business',
#   'sectionName': 'Business',
#   'webPublicationDate': '2020-11-07T19:00:18Z',
#   'webTitle': 'Biden lost Florida but he helped raise the minimum wage there. Policy matters | Greg Jericho',
#   'webUrl': 'https://www.theguardian.com/business/commentisfree/2020/nov/08/biden-lost-florida-but-he-helped-raise-the-minimum-wage-there-policy-matters',
#   'apiUrl': 'https://content.guardianapis.com/business/commentisfree/2020/nov/08/biden-lost-florida-but-he-helped-raise-the-minimum-wage-there-policy-matters',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'australia-news/2020/nov/05/joe-hockey-and-george-christensen-back-unfounded-claims-about-biden-comeback',
#   'type': 'article',
#   'sectionId': 'australia-news',
#   'sectionName': 'Australia news',
#   'webPublicationDate': '2020-11-05T02:30:30Z',
#   'webTitle': "Joe Hockey and George Christensen back unfounded 'fraud' claims about Biden comeback",
#   'webUrl': 'https://www.theguardian.com/australia-news/2020/nov/05/joe-hockey-and-george-christensen-back-unfounded-claims-about-biden-comeback',
#   'apiUrl': 'https://content.guardianapis.com/australia-news/2020/nov/05/joe-hockey-and-george-christensen-back-unfounded-claims-about-biden-comeback',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'us-news/2020/nov/02/polls-latest-biden-trump-key-states-election-2020',
#   'type': 'article',
#   'sectionId': 'us-news',
#   'sectionName': 'US news',
#   'webPublicationDate': '2020-11-03T01:33:57Z',
#   'webTitle': 'Latest election polls show Biden ahead but race tightening in key states',
#   'webUrl': 'https://www.theguardian.com/us-news/2020/nov/02/polls-latest-biden-trump-key-states-election-2020',
#   'apiUrl': 'https://content.guardianapis.com/us-news/2020/nov/02/polls-latest-biden-trump-key-states-election-2020',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'us-news/2020/nov/01/donald-trump-joe-biden-iowa-poll',
#   'type': 'article',
#   'sectionId': 'us-news',
#   'sectionName': 'US news',
#   'webPublicationDate': '2020-11-01T17:13:01Z',
#   'webTitle': 'Trump lead in Iowa poll rattles Democrats – but Biden still leads nationally',
#   'webUrl': 'https://www.theguardian.com/us-news/2020/nov/01/donald-trump-joe-biden-iowa-poll',
#   'apiUrl': 'https://content.guardianapis.com/us-news/2020/nov/01/donald-trump-joe-biden-iowa-poll',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'tv-and-radio/2020/nov/03/trump-v-biden-how-to-watch-the-us-election-coverage-in-the-uk',
#   'type': 'article',
#   'sectionId': 'tv-and-radio',
#   'sectionName': 'Television & radio',
#   'webPublicationDate': '2020-11-03T09:00:00Z',
#   'webTitle': 'Trump v Biden: how to watch the US election coverage in the UK',
#   'webUrl': 'https://www.theguardian.com/tv-and-radio/2020/nov/03/trump-v-biden-how-to-watch-the-us-election-coverage-in-the-uk',
#   'apiUrl': 'https://content.guardianapis.com/tv-and-radio/2020/nov/03/trump-v-biden-how-to-watch-the-us-election-coverage-in-the-uk',
#   'isHosted': False,
#   'pillarId': 'pillar/arts',
#   'pillarName': 'Arts'},
#  {'id': 'us-news/2020/nov/09/youth-turnout-us-election-biden-victory-young-voters',
#   'type': 'article',
#   'sectionId': 'us-news',
#   'sectionName': 'US news',
#   'webPublicationDate': '2020-11-09T07:00:03Z',
#   'webTitle': 'Surge in youth voter turnout may have helped propel Biden to victory',
#   'webUrl': 'https://www.theguardian.com/us-news/2020/nov/09/youth-turnout-us-election-biden-victory-young-voters',
#   'apiUrl': 'https://content.guardianapis.com/us-news/2020/nov/09/youth-turnout-us-election-biden-victory-young-voters',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'commentisfree/2020/nov/08/the-guardian-view-on-joe-biden-cometh-the-hour-cometh-the-man',
#   'type': 'article',
#   'sectionId': 'commentisfree',
#   'sectionName': 'Opinion',
#   'webPublicationDate': '2020-11-08T19:06:10Z',
#   'webTitle': 'The Guardian view on Joe Biden: cometh the hour, cometh the man | Editorial',
#   'webUrl': 'https://www.theguardian.com/commentisfree/2020/nov/08/the-guardian-view-on-joe-biden-cometh-the-hour-cometh-the-man',
#   'apiUrl': 'https://content.guardianapis.com/commentisfree/2020/nov/08/the-guardian-view-on-joe-biden-cometh-the-hour-cometh-the-man',
#   'isHosted': False,
#   'pillarId': 'pillar/opinion',
#   'pillarName': 'Opinion'},
#  {'id': 'us-news/2020/nov/08/can-joe-biden-and-kamala-harris-put-bitterly-divided-america-back-together',
#   'type': 'article',
#   'sectionId': 'us-news',
#   'sectionName': 'US news',
#   'webPublicationDate': '2020-11-08T16:00:44Z',
#   'webTitle': 'Can Biden and Harris put a bitterly divided America back together again?',
#   'webUrl': 'https://www.theguardian.com/us-news/2020/nov/08/can-joe-biden-and-kamala-harris-put-bitterly-divided-america-back-together',
#   'apiUrl': 'https://content.guardianapis.com/us-news/2020/nov/08/can-joe-biden-and-kamala-harris-put-bitterly-divided-america-back-together',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'politics/2020/nov/08/boris-johnson-under-pressure-to-avoid-no-deal-brexit-after-biden-victory',
#   'type': 'article',
#   'sectionId': 'politics',
#   'sectionName': 'Politics',
#   'webPublicationDate': '2020-11-08T09:00:35Z',
#   'webTitle': 'Boris Johnson under pressure to avoid no-deal Brexit after Biden victory',
#   'webUrl': 'https://www.theguardian.com/politics/2020/nov/08/boris-johnson-under-pressure-to-avoid-no-deal-brexit-after-biden-victory',
#   'apiUrl': 'https://content.guardianapis.com/politics/2020/nov/08/boris-johnson-under-pressure-to-avoid-no-deal-brexit-after-biden-victory',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'us-news/2020/nov/07/joe-biden-victory-speech-donald-trump-kamala-harris',
#   'type': 'article',
#   'sectionId': 'us-news',
#   'sectionName': 'US news',
#   'webPublicationDate': '2020-11-08T05:28:18Z',
#   'webTitle': "With humility and empathy, Biden speech seeks to make America sane again | David Smith's sketch",
#   'webUrl': 'https://www.theguardian.com/us-news/2020/nov/07/joe-biden-victory-speech-donald-trump-kamala-harris',
#   'apiUrl': 'https://content.guardianapis.com/us-news/2020/nov/07/joe-biden-victory-speech-donald-trump-kamala-harris',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'media/2020/nov/05/fox-news-sucks-trump-supporters',
#   'type': 'article',
#   'sectionId': 'media',
#   'sectionName': 'Media',
#   'webPublicationDate': '2020-11-06T06:00:03Z',
#   'webTitle': "'Fox News sucks!': Trump supporters decry channel as it declares Biden wins",
#   'webUrl': 'https://www.theguardian.com/media/2020/nov/05/fox-news-sucks-trump-supporters',
#   'apiUrl': 'https://content.guardianapis.com/media/2020/nov/05/fox-news-sucks-trump-supporters',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'australia-news/2020/nov/05/morning-mail-us-election-still-too-close-to-call-queensland-wins-origin-opener',
#   'type': 'article',
#   'sectionId': 'australia-news',
#   'sectionName': 'Australia news',
#   'webPublicationDate': '2020-11-04T20:04:40Z',
#   'webTitle': "Morning mail: Biden takes Wisconsin, Denmark's mink cull, Maroons win Origin I",
#   'webUrl': 'https://www.theguardian.com/australia-news/2020/nov/05/morning-mail-us-election-still-too-close-to-call-queensland-wins-origin-opener',
#   'apiUrl': 'https://content.guardianapis.com/australia-news/2020/nov/05/morning-mail-us-election-still-too-close-to-call-queensland-wins-origin-opener',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'us-news/2020/nov/04/latino-voters-joe-biden-support-hillary-clinton',
#   'type': 'article',
#   'sectionId': 'us-news',
#   'sectionName': 'US news',
#   'webPublicationDate': '2020-11-04T09:02:17Z',
#   'webTitle': 'Latinos offer lukewarm enthusiasm for Biden after Democrat fails to woo voters',
#   'webUrl': 'https://www.theguardian.com/us-news/2020/nov/04/latino-voters-joe-biden-support-hillary-clinton',
#   'apiUrl': 'https://content.guardianapis.com/us-news/2020/nov/04/latino-voters-joe-biden-support-hillary-clinton',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'us-news/2020/nov/02/trump-biden-coronavirus-covid-lockdown',
#   'type': 'article',
#   'sectionId': 'us-news',
#   'sectionName': 'US news',
#   'webPublicationDate': '2020-11-02T17:43:00Z',
#   'webTitle': 'Donald Trump tries to stoke fears of Covid lockdown under Joe Biden',
#   'webUrl': 'https://www.theguardian.com/us-news/2020/nov/02/trump-biden-coronavirus-covid-lockdown',
#   'apiUrl': 'https://content.guardianapis.com/us-news/2020/nov/02/trump-biden-coronavirus-covid-lockdown',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'us-news/2020/nov/02/uk-embassy-regarded-joe-biden-past-his-best-kim-darroch',
#   'type': 'article',
#   'sectionId': 'us-news',
#   'sectionName': 'US news',
#   'webPublicationDate': '2020-11-02T16:23:13Z',
#   'webTitle': "UK embassy regarded Joe Biden as 'past his best', says Kim Darroch",
#   'webUrl': 'https://www.theguardian.com/us-news/2020/nov/02/uk-embassy-regarded-joe-biden-past-his-best-kim-darroch',
#   'apiUrl': 'https://content.guardianapis.com/us-news/2020/nov/02/uk-embassy-regarded-joe-biden-past-his-best-kim-darroch',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'us-news/live/2020/nov/06/us-election-joe-biden-donald-trump-result-latest-who-is-winning-live-2020-updates',
#   'type': 'liveblog',
#   'sectionId': 'us-news',
#   'sectionName': 'US news',
#   'webPublicationDate': '2020-11-07T17:54:25Z',
#   'webTitle': 'Joe Biden beats Donald Trump to win US election 2020 – as it happened',
#   'webUrl': 'https://www.theguardian.com/us-news/live/2020/nov/06/us-election-joe-biden-donald-trump-result-latest-who-is-winning-live-2020-updates',
#   'apiUrl': 'https://content.guardianapis.com/us-news/live/2020/nov/06/us-election-joe-biden-donald-trump-result-latest-who-is-winning-live-2020-updates',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'us-news/2020/nov/08/joe-biden-wins-election-share-your-views',
#   'type': 'article',
#   'sectionId': 'us-news',
#   'sectionName': 'US news',
#   'webPublicationDate': '2020-11-08T11:00:37Z',
#   'webTitle': 'How do you feel? Share your reaction to Joe Biden winning the US election',
#   'webUrl': 'https://www.theguardian.com/us-news/2020/nov/08/joe-biden-wins-election-share-your-views',
#   'apiUrl': 'https://content.guardianapis.com/us-news/2020/nov/08/joe-biden-wins-election-share-your-views',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'business/2020/nov/06/the-risks-are-now-off-the-table-wall-street-looks-forward-to-biden-presidency',
#   'type': 'article',
#   'sectionId': 'business',
#   'sectionName': 'Business',
#   'webPublicationDate': '2020-11-06T13:00:46Z',
#   'webTitle': '‘The risks are now off the table’: Wall Street looks forward to Biden presidency',
#   'webUrl': 'https://www.theguardian.com/business/2020/nov/06/the-risks-are-now-off-the-table-wall-street-looks-forward-to-biden-presidency',
#   'apiUrl': 'https://content.guardianapis.com/business/2020/nov/06/the-risks-are-now-off-the-table-wall-street-looks-forward-to-biden-presidency',
# ...
#   'apiUrl': 'https://content.guardianapis.com/us-news/2020/nov/01/trump-has-gone-a-long-way-toward-hindering-democracy-in-other-countries',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'commentisfree/2020/nov/05/lockdown-nigel-farage-new-enemy-us-election-covid-19',
#   'type': 'article',
#   'sectionId': 'commentisfree',
#   'sectionName': 'Opinion',
#   'webPublicationDate': '2020-11-05T10:23:36Z',
#   'webTitle': "Here's why lockdown is Nigel Farage’s new target | Darren Loucaides",
#   'webUrl': 'https://www.theguardian.com/commentisfree/2020/nov/05/lockdown-nigel-farage-new-enemy-us-election-covid-19',
#   'apiUrl': 'https://content.guardianapis.com/commentisfree/2020/nov/05/lockdown-nigel-farage-new-enemy-us-election-covid-19',
#   'isHosted': False,
#   'pillarId': 'pillar/opinion',
#   'pillarName': 'Opinion'},
#  {'id': 'membership/2020/nov/02/reporting-the-us-election-no-one-quite-knows-when-it-will-end-or-how',
#   'type': 'article',
#   'sectionId': 'membership',
#   'sectionName': 'Membership',
#   'webPublicationDate': '2020-11-02T07:00:43Z',
#   'webTitle': "Reporting the US election: 'No one quite knows when it will end. Or how'",
#   'webUrl': 'https://www.theguardian.com/membership/2020/nov/02/reporting-the-us-election-no-one-quite-knows-when-it-will-end-or-how',
#   'apiUrl': 'https://content.guardianapis.com/membership/2020/nov/02/reporting-the-us-election-no-one-quite-knows-when-it-will-end-or-how',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'world/live/2020/nov/03/coronavirus-live-news-france-sees-record-new-cases-who-warns-its-not-too-late-to-take-critical-action',
#   'type': 'liveblog',
#   'sectionId': 'world',
#   'sectionName': 'World news',
#   'webPublicationDate': '2020-11-03T23:28:50Z',
#   'webTitle': "Italy fears 'tsunami' of coronavirus patients – as it happened",
#   'webUrl': 'https://www.theguardian.com/world/live/2020/nov/03/coronavirus-live-news-france-sees-record-new-cases-who-warns-its-not-too-late-to-take-critical-action',
#   'apiUrl': 'https://content.guardianapis.com/world/live/2020/nov/03/coronavirus-live-news-france-sees-record-new-cases-who-warns-its-not-too-late-to-take-critical-action',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'commentisfree/2020/nov/09/with-trump-voted-out-can-i-finally-feel-at-home-in-america-again',
#   'type': 'article',
#   'sectionId': 'commentisfree',
#   'sectionName': 'Opinion',
#   'webPublicationDate': '2020-11-09T14:00:53Z',
#   'webTitle': 'With Trump voted out, can I finally feel at home in America again? | Moustafa Bayoumi',
#   'webUrl': 'https://www.theguardian.com/commentisfree/2020/nov/09/with-trump-voted-out-can-i-finally-feel-at-home-in-america-again',
#   'apiUrl': 'https://content.guardianapis.com/commentisfree/2020/nov/09/with-trump-voted-out-can-i-finally-feel-at-home-in-america-again',
#   'isHosted': False,
#   'pillarId': 'pillar/opinion',
#   'pillarName': 'Opinion'},
#  {'id': 'film/2020/nov/08/gabriel-byrne-its-an-obscenity-to-tell-innocent-children-theyre-going-to-hell',
#   'type': 'article',
#   'sectionId': 'film',
#   'sectionName': 'Film',
#   'webPublicationDate': '2020-11-08T14:00:41Z',
#   'webTitle': "Gabriel Byrne: 'There’s a shame about men speaking out. A sense that if you were abused, it was your fault'",
#   'webUrl': 'https://www.theguardian.com/film/2020/nov/08/gabriel-byrne-its-an-obscenity-to-tell-innocent-children-theyre-going-to-hell',
#   'apiUrl': 'https://content.guardianapis.com/film/2020/nov/08/gabriel-byrne-its-an-obscenity-to-tell-innocent-children-theyre-going-to-hell',
#   'isHosted': False,
#   'pillarId': 'pillar/arts',
#   'pillarName': 'Arts'},
#  {'id': 'commentisfree/2020/nov/03/feeling-powerless-how-foreigners-can-survive-the-us-election-without-complete-nervous-collapse',
#   'type': 'article',
#   'sectionId': 'commentisfree',
#   'sectionName': 'Opinion',
#   'webPublicationDate': '2020-11-02T23:53:18Z',
#   'webTitle': 'Feeling powerless? How foreigners can survive the US election without complete nervous collapse | Van Badham',
#   'webUrl': 'https://www.theguardian.com/commentisfree/2020/nov/03/feeling-powerless-how-foreigners-can-survive-the-us-election-without-complete-nervous-collapse',
#   'apiUrl': 'https://content.guardianapis.com/commentisfree/2020/nov/03/feeling-powerless-how-foreigners-can-survive-the-us-election-without-complete-nervous-collapse',
#   'isHosted': False,
#   'pillarId': 'pillar/opinion',
#   'pillarName': 'Opinion'},
#  {'id': 'australia-news/2020/nov/02/morning-mail-trump-poll-boost-messages-revealed-in-taylor-moore-row-new-climate-warning',
#   'type': 'article',
#   'sectionId': 'australia-news',
#   'sectionName': 'Australia news',
#   'webPublicationDate': '2020-11-01T19:56:51Z',
#   'webTitle': 'Morning mail: Trump poll boost, messages revealed in Taylor-Moore row, new climate warning',
#   'webUrl': 'https://www.theguardian.com/australia-news/2020/nov/02/morning-mail-trump-poll-boost-messages-revealed-in-taylor-moore-row-new-climate-warning',
#   'apiUrl': 'https://content.guardianapis.com/australia-news/2020/nov/02/morning-mail-trump-poll-boost-messages-revealed-in-taylor-moore-row-new-climate-warning',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'world/2020/nov/09/covid-19-vaccine-candidate-effective-pfizer-biontech',
#   'type': 'article',
#   'sectionId': 'world',
#   'sectionName': 'World news',
#   'webPublicationDate': '2020-11-10T05:40:21Z',
#   'webTitle': 'Hopes rise for end of pandemic as Pfizer says vaccine has 90% efficacy',
#   'webUrl': 'https://www.theguardian.com/world/2020/nov/09/covid-19-vaccine-candidate-effective-pfizer-biontech',
#   'apiUrl': 'https://content.guardianapis.com/world/2020/nov/09/covid-19-vaccine-candidate-effective-pfizer-biontech',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'australia-news/live/2020/nov/10/australian-politics-live-coalition-labor-morrison-albanese-porter-tudge-abc-turnbull',
#   'type': 'liveblog',
#   'sectionId': 'australia-news',
#   'sectionName': 'Australia news',
#   'webPublicationDate': '2020-11-10T07:52:41Z',
#   'webTitle': "Labor questions Coalition decision to cut jobseeker during 'worst recession in almost a century' – as it happened",
#   'webUrl': 'https://www.theguardian.com/australia-news/live/2020/nov/10/australian-politics-live-coalition-labor-morrison-albanese-porter-tudge-abc-turnbull',
#   'apiUrl': 'https://content.guardianapis.com/australia-news/live/2020/nov/10/australian-politics-live-coalition-labor-morrison-albanese-porter-tudge-abc-turnbull',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'australia-news/2020/nov/04/morning-mail-america-votes-melbourne-cup-tragedy-poland-delays-abortion-law',
#   'type': 'article',
#   'sectionId': 'australia-news',
#   'sectionName': 'Australia news',
#   'webPublicationDate': '2020-11-03T19:52:36Z',
#   'webTitle': 'Morning mail: America votes, Melbourne Cup tragedy, Poland delays abortion law',
#   'webUrl': 'https://www.theguardian.com/australia-news/2020/nov/04/morning-mail-america-votes-melbourne-cup-tragedy-poland-delays-abortion-law',
#   'apiUrl': 'https://content.guardianapis.com/australia-news/2020/nov/04/morning-mail-america-votes-melbourne-cup-tragedy-poland-delays-abortion-law',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'business/2020/nov/01/end-of-oil-and-beginnings-of-a-low-carbon-planet',
#   'type': 'article',
#   'sectionId': 'business',
#   'sectionName': 'Business',
#   'webPublicationDate': '2020-11-01T09:00:16Z',
#   'webTitle': 'On the horizon: the end of oil and the beginnings of a low-carbon planet',
#   'webUrl': 'https://www.theguardian.com/business/2020/nov/01/end-of-oil-and-beginnings-of-a-low-carbon-planet',
#   'apiUrl': 'https://content.guardianapis.com/business/2020/nov/01/end-of-oil-and-beginnings-of-a-low-carbon-planet',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'us-news/2020/nov/06/employers-and-co-workers-want-black-womens-expertise-but-are-they-paying-them-for-it',
#   'type': 'article',
#   'sectionId': 'us-news',
#   'sectionName': 'US news',
#   'webPublicationDate': '2020-11-06T06:00:04Z',
#   'webTitle': "Employers and co-workers want Black women's expertise. But are they paying them for it?",
#   'webUrl': 'https://www.theguardian.com/us-news/2020/nov/06/employers-and-co-workers-want-black-womens-expertise-but-are-they-paying-them-for-it',
#   'apiUrl': 'https://content.guardianapis.com/us-news/2020/nov/06/employers-and-co-workers-want-black-womens-expertise-but-are-they-paying-them-for-it',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'world/live/2020/nov/01/coronavirus-live-updates-australia-uk-boris-johnson-lockdown-us-record-daily-cases',
#   'type': 'liveblog',
#   'sectionId': 'world',
#   'sectionName': 'World news',
#   'webPublicationDate': '2020-11-01T23:39:42Z',
#   'webTitle': 'Iran death toll hits daily record of 434 – as it happened',
#   'webUrl': 'https://www.theguardian.com/world/live/2020/nov/01/coronavirus-live-updates-australia-uk-boris-johnson-lockdown-us-record-daily-cases',
#   'apiUrl': 'https://content.guardianapis.com/world/live/2020/nov/01/coronavirus-live-updates-australia-uk-boris-johnson-lockdown-us-record-daily-cases',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'australia-news/live/2020/nov/03/trade-tensions-china-escalate-nsw-health-victoria-queensland-covid-19-live-news',
#   'type': 'liveblog',
#   'sectionId': 'australia-news',
#   'sectionName': 'Australia news',
#   'webPublicationDate': '2020-11-03T08:38:33Z',
#   'webTitle': 'Cash rate cut to new historic low of 0.1% – as it happened',
#   'webUrl': 'https://www.theguardian.com/australia-news/live/2020/nov/03/trade-tensions-china-escalate-nsw-health-victoria-queensland-covid-19-live-news',
#   'apiUrl': 'https://content.guardianapis.com/australia-news/live/2020/nov/03/trade-tensions-china-escalate-nsw-health-victoria-queensland-covid-19-live-news',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'business/live/2020/nov/02/lockdown-markets-oil-travel-retailers-ftse-low-manufacturing-ocado-primark-business-live',
#   'type': 'liveblog',
#   'sectionId': 'business',
#   'sectionName': 'Business',
#   'webPublicationDate': '2020-11-02T19:39:47Z',
#   'webTitle': 'Markets rise despite Covid-19 lockdown double-dip fears – as it happened',
#   'webUrl': 'https://www.theguardian.com/business/live/2020/nov/02/lockdown-markets-oil-travel-retailers-ftse-low-manufacturing-ocado-primark-business-live',
#   'apiUrl': 'https://content.guardianapis.com/business/live/2020/nov/02/lockdown-markets-oil-travel-retailers-ftse-low-manufacturing-ocado-primark-business-live',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'artanddesign/2020/nov/09/tracey-emin-cancer-love-exhibitions-pyjamas-birdsong',
#   'type': 'article',
#   'sectionId': 'artanddesign',
#   'sectionName': 'Art and design',
#   'webPublicationDate': '2020-11-09T06:00:01Z',
#   'webTitle': "Tracey Emin on her cancer: 'I will find love. I will have exhibitions. I will enjoy life'",
#   'webUrl': 'https://www.theguardian.com/artanddesign/2020/nov/09/tracey-emin-cancer-love-exhibitions-pyjamas-birdsong',
#   'apiUrl': 'https://content.guardianapis.com/artanddesign/2020/nov/09/tracey-emin-cancer-love-exhibitions-pyjamas-birdsong',
#   'isHosted': False,
#   'pillarId': 'pillar/arts',
#   'pillarName': 'Arts'},
#  {'id': 'world/live/2020/nov/07/coronavirus-live-news-italy-begins-nightly-curfew-victoria-has-eighth-straight-day-of-no-cases',
#   'type': 'liveblog',
#   'sectionId': 'world',
#   'sectionName': 'World news',
#   'webPublicationDate': '2020-11-08T01:26:02Z',
#   'webTitle': 'UK reports 413 deaths; Trump chief of staff tests positive for Covid – as it happened',
#   'webUrl': 'https://www.theguardian.com/world/live/2020/nov/07/coronavirus-live-news-italy-begins-nightly-curfew-victoria-has-eighth-straight-day-of-no-cases',
#   'apiUrl': 'https://content.guardianapis.com/world/live/2020/nov/07/coronavirus-live-news-italy-begins-nightly-curfew-victoria-has-eighth-straight-day-of-no-cases',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'world/live/2020/nov/10/coronavirus-live-news-who-warns-covid-not-tired-of-us-as-top-uk-scientist-says-vaccine-feels-like-watershed-moment',
#   'type': 'liveblog',
#   'sectionId': 'world',
#   'sectionName': 'World news',
#   'webPublicationDate': '2020-11-10T23:55:55Z',
#   'webTitle': "Greek football players attend 'coronavirus party' – as it happened",
#   'webUrl': 'https://www.theguardian.com/world/live/2020/nov/10/coronavirus-live-news-who-warns-covid-not-tired-of-us-as-top-uk-scientist-says-vaccine-feels-like-watershed-moment',
#   'apiUrl': 'https://content.guardianapis.com/world/live/2020/nov/10/coronavirus-live-news-who-warns-covid-not-tired-of-us-as-top-uk-scientist-says-vaccine-feels-like-watershed-moment',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'world/live/2020/nov/06/coronavirus-live-news-us-records-global-record-102000-new-cases-as-world-suffers-highest-daily-deaths',
#   'type': 'liveblog',
#   'sectionId': 'world',
#   'sectionName': 'World news',
#   'webPublicationDate': '2020-11-07T00:21:25Z',
#   'webTitle': 'France reports record 60,486 new cases; Russia saw 9,798 deaths in September – as it happened',
#   'webUrl': 'https://www.theguardian.com/world/live/2020/nov/06/coronavirus-live-news-us-records-global-record-102000-new-cases-as-world-suffers-highest-daily-deaths',
#   'apiUrl': 'https://content.guardianapis.com/world/live/2020/nov/06/coronavirus-live-news-us-records-global-record-102000-new-cases-as-world-suffers-highest-daily-deaths',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'business/live/2020/nov/10/uk-unemployment-redundancies-record-high-covid-19-markets-business-live',
#   'type': 'liveblog',
#   'sectionId': 'business',
#   'sectionName': 'Business',
#   'webPublicationDate': '2020-11-10T17:14:20Z',
#   'webTitle': 'FTSE 100 vaccine rally continues; UK unemployment jumps – as it happened',
#   'webUrl': 'https://www.theguardian.com/business/live/2020/nov/10/uk-unemployment-redundancies-record-high-covid-19-markets-business-live',
#   'apiUrl': 'https://content.guardianapis.com/business/live/2020/nov/10/uk-unemployment-redundancies-record-high-covid-19-markets-business-live',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'australia-news/live/2020/nov/02/australia-coronavirus-live-hunt-vaccine-border-nsw-qld-victoria-covid-19-continue-live-updates',
#   'type': 'liveblog',
#   'sectionId': 'australia-news',
#   'sectionName': 'Australia news',
#   'webPublicationDate': '2020-11-02T08:27:07Z',
#   'webTitle': 'Ministers pay tribute to Christine Holgate – as it happened',
#   'webUrl': 'https://www.theguardian.com/australia-news/live/2020/nov/02/australia-coronavirus-live-hunt-vaccine-border-nsw-qld-victoria-covid-19-continue-live-updates',
#   'apiUrl': 'https://content.guardianapis.com/australia-news/live/2020/nov/02/australia-coronavirus-live-hunt-vaccine-border-nsw-qld-victoria-covid-19-continue-live-updates',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'},
#  {'id': 'world/live/2020/nov/03/vienna-austria-synagogue-terror-attack-police-live-updates',
#   'type': 'liveblog',
#   'sectionId': 'world',
#   'sectionName': 'World news',
#   'webPublicationDate': '2020-11-03T13:32:50Z',
#   'webTitle': 'Vienna shooting: fourth victim dies as police make several arrests - as it happened',
#   'webUrl': 'https://www.theguardian.com/world/live/2020/nov/03/vienna-austria-synagogue-terror-attack-police-live-updates',
#   'apiUrl': 'https://content.guardianapis.com/world/live/2020/nov/03/vienna-austria-synagogue-terror-attack-police-live-updates',
#   'isHosted': False,
#   'pillarId': 'pillar/news',
#   'pillarName': 'News'}]

# %%
import pandas as pd

# %%
df = pd.DataFrame(results)

# %%
df.tail()
# Out:
#                                                     id      type  \
# 469  world/live/2020/nov/10/coronavirus-live-news-w...  liveblog
# 470  world/live/2020/nov/06/coronavirus-live-news-u...  liveblog
# 471  business/live/2020/nov/10/uk-unemployment-redu...  liveblog
# 472  australia-news/live/2020/nov/02/australia-coro...  liveblog
# 473  world/live/2020/nov/03/vienna-austria-synagogu...  liveblog
#
#           sectionId     sectionName    webPublicationDate  \
# 469           world      World news  2020-11-10T23:55:55Z
# 470           world      World news  2020-11-07T00:21:25Z
# 471        business        Business  2020-11-10T17:14:20Z
# 472  australia-news  Australia news  2020-11-02T08:27:07Z
# 473           world      World news  2020-11-03T13:32:50Z
#
#                                               webTitle  \
# 469  Greek football players attend 'coronavirus par...
# 470  France reports record 60,486 new cases; Russia...
# 471  FTSE 100 vaccine rally continues; UK unemploym...
# 472  Ministers pay tribute to Christine Holgate – a...
# 473  Vienna shooting: fourth victim dies as police ...
#
#                                                 webUrl  \
# 469  https://www.theguardian.com/world/live/2020/no...
# 470  https://www.theguardian.com/world/live/2020/no...
# 471  https://www.theguardian.com/business/live/2020...
# 472  https://www.theguardian.com/australia-news/liv...
# 473  https://www.theguardian.com/world/live/2020/no...
#
#                                                 apiUrl  isHosted     pillarId  \
# 469  https://content.guardianapis.com/world/live/20...     False  pillar/news
# 470  https://content.guardianapis.com/world/live/20...     False  pillar/news
# 471  https://content.guardianapis.com/business/live...     False  pillar/news
# 472  https://content.guardianapis.com/australia-new...     False  pillar/news
# 473  https://content.guardianapis.com/world/live/20...     False  pillar/news
#
#     pillarName
# 469       News
# 470       News
# 471       News
# 472       News
# 473       News

# %%
df["webPublicationDate"] = pd.to_datetime(df["webPublicationDate"])

# %%
df.head()
# Out:
#                                                   id      type  \
# 0  australia-news/2020/nov/05/biden-edges-closer-...   article
# 1  politics/2020/nov/10/johnsons-biden-win-tweet-...   article
# 2  us-news/live/2020/nov/07/us-election-joe-biden...  liveblog
# 3  us-news/2020/nov/08/donald-trump-concede-legal...   article
# 4  us-news/2020/nov/07/joe-biden-disunited-states...   article
#
#         sectionId     sectionName        webPublicationDate  \
# 0  australia-news  Australia news 2020-11-05 05:38:22+00:00
# 1        politics        Politics 2020-11-10 13:19:16+00:00
# 2         us-news         US news 2020-11-08 10:04:24+00:00
# 3         us-news         US news 2020-11-08 19:39:23+00:00
# 4         us-news         US news 2020-11-07 10:00:07+00:00
#
#                                             webTitle  \
# 0  US election briefing for Australia: Biden edge...
# 1  Johnson's Biden win tweet contains hidden Trum...
# 2  Biden addresses Americans after victory – as i...
# 3  Republicans back Trump challenge to Biden elec...
# 4  Joe Biden poised to inherit Disunited States o...
#
#                                               webUrl  \
# 0  https://www.theguardian.com/australia-news/202...
# 1  https://www.theguardian.com/politics/2020/nov/...
# 2  https://www.theguardian.com/us-news/live/2020/...
# 3  https://www.theguardian.com/us-news/2020/nov/0...
# 4  https://www.theguardian.com/us-news/2020/nov/0...
#
#                                               apiUrl  isHosted     pillarId  \
# 0  https://content.guardianapis.com/australia-new...     False  pillar/news
# 1  https://content.guardianapis.com/politics/2020...     False  pillar/news
# 2  https://content.guardianapis.com/us-news/live/...     False  pillar/news
# 3  https://content.guardianapis.com/us-news/2020/...     False  pillar/news
# 4  https://content.guardianapis.com/us-news/2020/...     False  pillar/news
#
#   pillarName
# 0       News
# 1       News
# 2       News
# 3       News
# 4       News

# %%
# Get the day and day name, then count them.
date = df["webPublicationDate"].dt
# dates = pd.DataFrame({"day": date.day, "day_name": date.day_name()}
date

# %%
date.day_name()

# %%
dates = pd.DataFrame({"day": date.day, "day_name": date.day_name()})

# %%
dates

# %% [markdown]
# Write it as a function

# %%
def get_articles(q, page = 1):
    response = requests.get("https://content.guardianapis.com/search", params = {
        "api-key": key,
        "q": q,
        "from-date": "2020-11-01",
        "to-date": "2020-11-05",
        "page-size": 50,
        "page": page
    })
    response.raise_for_status()
    return response.json()["response"]

# %%
def get_all_articles(q, time_sleep = 0.1):
    # Get the first page, and find out how many pages there are.
    # NOTE: We could make this function clearer by renaming the `biden` variable,
    # since the function might be searching for something else.
    candidate = get_articles(q)
    pages = candidate["pages"]

    # Loop over remaining pages.
    results = candidate["results"]
    for p in range(2, pages + 1):
        results += get_articles(q, p)["results"]
        time.sleep(time_sleep)

    # Convert the articles to data frame, and the date column to a date.
    df = pd.DataFrame(results)
    df["webPublicationDate"] = pd.to_datetime(df["webPublicationDate"])
    
    # Get the day and day name, then count them.
    date = df["webPublicationDate"].dt
    dates = pd.DataFrame({"day": date.day, "day_name": date.day_name()})
    return dates.groupby(["day", "day_name"]).size()

# %%
print(get_all_articles("Biden"))
# Out:
# day  day_name
# 1    Sunday       29
# 2    Monday       26
# 3    Tuesday      49
# 4    Wednesday    60
# 5    Thursday     40
# dtype: int64

# %%
print(get_all_articles("Trump"))
# Out:
# day  day_name
# 1    Sunday       47
# 2    Monday       37
# 3    Tuesday      56
# 4    Wednesday    64
# 5    Thursday     49
# dtype: int64

# %% [markdown]
# What are some ways this analysis could be improved?
#
# * Check that articles about "Trump" and "Biden" are actually about the two candidates. Some may be about other things -- the English word "trump", "Hunter Biden", etc...
# * Check whether the API searches article text or just article titles.
# * Use more sources, and use American newspapers (unless the goal was to analyze international news).
# * Make visualizations.
# * Use a larger time window.
# * Use other kinds of data (e.g., poll results) to look for relationships.
#
# Collecting and cleaning data takes a lot of very technical work, but it's only the first step in the analysis. When you finish data collection and cleaning, it can feel like you're finally done. Take a moment to congratulate yourself and step away from the data, so that when you come back you'll be ready to do a careful statistical analysis.

# %% [markdown]
# ### OAuth
#
# [OAuth](https://en.wikipedia.org/wiki/OAuth) is a way to give an application access to data on a website or web API.
#
# You might run into OAuth if you use a web API where the data is private. For instance, Twitter provides a [web API](https://developer.twitter.com/en/docs.html) for managing your personal Twitter account. If you want to access the API from a Python script, first you have to use OAuth to tell Twitter that the script has permission to use your data.
#
# OAuth can operate in several different ways. As always, check the documentation for the web API you want to use in order to find out what you need to do.
#
# The simplest case of OAuth requires scripts to have a key or token from the web API provider. This is very similar to using an API key.
#
# For more complicated cases, the **requests-ouathlib** package (documentation [here](https://requests-oauthlib.readthedocs.io/en/latest/)) may help.

# %% [markdown]
# ## Undocumented Web APIs
#
# Many websites use undocumented web APIs to get data. For example:
#
# * [University of California Compensation](https://ucannualwage.ucop.edu/wage/)
# * [Yolo County Health Inspections](https://yoloeco.envisionconnect.com/)
#
# You can identify these websites by looking at requests in your browser's developer tools. In Firefox or Chrome, you can open the developer tools with `ctrl-shift-i`.
#
# Requests to web APIs almost always return JSON or XML data. By examining the browser requests, you can work out the endpoints and parameters, allowing you to use the API.
#
# **CAUTION:** Web APIs that are undocumented are often undocumented for a reason. Using an undocumented API may make someone angry or get you into legal trouble! Government and quasi-government websites (like the examples above) are probably okay, as long as you cache and rate-limit your requests. For everything else, find for an alternative or get permission first.

# %% [markdown]
# Let's reverse engineer the Yolo County Health Inspections web API so that we can get data about local restaurants.

# %%
# install requests-cache package 
# !pip install requests-cache
# Out:
# Requirement already satisfied: requests-cache in /Users/yuchien/opt/anaconda3/lib/python3.8/site-packages (0.8.1)
# Requirement already satisfied: attrs<22.0,>=21.2 in /Users/yuchien/opt/anaconda3/lib/python3.8/site-packages (from requests-cache) (21.2.0)
# Requirement already satisfied: url-normalize<2.0,>=1.4 in /Users/yuchien/opt/anaconda3/lib/python3.8/site-packages (from requests-cache) (1.4.3)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.4 in /Users/yuchien/opt/anaconda3/lib/python3.8/site-packages (from requests-cache) (1.4.4)
# Requirement already satisfied: cattrs<2.0,>=1.8 in /Users/yuchien/opt/anaconda3/lib/python3.8/site-packages (from requests-cache) (1.8.0)
# Requirement already satisfied: requests<3.0,>=2.22 in /Users/yuchien/opt/anaconda3/lib/python3.8/site-packages (from requests-cache) (2.25.1)
# Requirement already satisfied: urllib3<2.0.0,>=1.25.5 in /Users/yuchien/opt/anaconda3/lib/python3.8/site-packages (from requests-cache) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/yuchien/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0,>=2.22->requests-cache) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /Users/yuchien/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0,>=2.22->requests-cache) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/yuchien/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0,>=2.22->requests-cache) (4.0.0)
# Requirement already satisfied: six in /Users/yuchien/opt/anaconda3/lib/python3.8/site-packages (from url-normalize<2.0,>=1.4->requests-cache) (1.15.0)

# %%
import numpy as np
import pandas as pd
import requests
import requests_cache

requests_cache.install_cache("mycache")

# %%
def get_health_info(q):
    response = requests.post("https://yoloeco.envisionconnect.com/api/pressAgentClient/searchFacilities", params = {
        "PressAgentOid": "c08cb189-894c-4c8c-b595-a5ef010226b4",
    }, json = {
        'FacilityId': q
        # "FacilityName": q,
        # "LastScore": p
        # "Address": p
    })

    response.raise_for_status()
    #"FacilityName": "pluto's"

    # Different ways to attach data to a POST request:
    # With data=, we get a query string
    #   FacilityName=pluto's

    # With json=, we get a json object

    return response.json()


result = get_health_info("FA")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-56-f88468cd07c3> in <module>
#      21
#      22
# ---> 23 result = get_health_info("FA")
#
# <ipython-input-56-f88468cd07c3> in get_health_info(q)
#       9     })
#      10
# ---> 11     response.raise_for_status()
#      12     #"FacilityName": "pluto's"
#      13
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/models.py in raise_for_status(self)
#     941
#     942         if http_error_msg:
# --> 943             raise HTTPError(http_error_msg, response=self)
#     944
#     945     def close(self):
#
# HTTPError: 500 Server Error: Internal Server Error for url: https://yoloeco.envisionconnect.com/api/pressAgentClient/searchFacilities?PressAgentOid=c08cb189-894c-4c8c-b595-a5ef010226b4

# %% [markdown]
# We could reverse engineer other parts of the API to get detailed data about health violations.

# %%
result = get_health_info("CREPE")
result
# Out:
# [{'FacilityId': 'FA0004831',
#   'FacilityName': 'CREPEVILLE DAVIS',
#   'Address': '330 3RD ST ',
#   'CityStateZip': 'DAVIS CA 95616 ',
#   'LastScore': 100.0,
#   'attachmentId': '78dc0f32-9160-4820-b5c4-ad2b00fdb87a'}]

# %%
result = get_health_info("a")

# %%
result
# Out:
# [{'FacilityId': 'FA0021354',
#   'FacilityName': 'A KE TACO',
#   'Address': '1900 PARKWOOD DR ',
#   'CityStateZip': 'YUBA CITY CA 95993 ',
#   'LastScore': 100.0,
#   'attachmentId': 'c5bf43d6-aa71-416f-b95a-ad4f00b3cda4'},
#  {'FacilityId': 'FA0019474',
#   'FacilityName': 'ACOUSTIC EVENTS',
#   'Address': '4467 D ST ',
#   'CityStateZip': 'SACRAMENTO CA 95819 ',
#   'LastScore': 100.0,
#   'attachmentId': '17afd99d-fe2b-4627-98a7-acb60091e364'},
#  {'FacilityId': 'FA0014014',
#   'FacilityName': 'AFC SUSHI / HOT WOK @ BEL AIR #526',
#   'Address': '1885 E GIBSON RD ',
#   'CityStateZip': 'WOODLAND CA 95776 ',
#   'LastScore': 100.0,
#   'attachmentId': None},
#  {'FacilityId': 'FA0014013',
#   'FacilityName': "AFC SUSHI / HOT WOK @ RALEY'S #206",
#   'Address': '367 W MAIN ST ',
#   'CityStateZip': 'WOODLAND CA 95695 ',
#   'LastScore': 100.0,
#   'attachmentId': None},
#  {'FacilityId': 'FA0014015',
#   'FacilityName': "AFC SUSHI / HOT WOK @ RALEY'S #448",
#   'Address': '1601 W CAPITOL AVE ',
#   'CityStateZip': 'WEST SACRAMENTO CA 95691 ',
#   'LastScore': 100.0,
#   'attachmentId': 'a8d24d51-da4b-4be3-9cf4-ad4e0110d37c'},
#  {'FacilityId': 'FA0010191',
#   'FacilityName': 'AFC SUSHI @ SAFEWAY #1205',
#   'Address': '1451 W COVELL BLVD ',
#   'CityStateZip': 'DAVIS CA 95616 ',
#   'LastScore': 100.0,
#   'attachmentId': '59be27cd-feed-41d0-ac11-ae1b00e0793e'},
#  {'FacilityId': 'FA0010190',
#   'FacilityName': 'AFC SUSHI @ SAFEWAY #1561',
#   'Address': '2121 COWELL BLVD ',
#   'CityStateZip': 'DAVIS CA 95616 ',
#   'LastScore': 100.0,
#   'attachmentId': 'd9e3e620-56d4-4499-876f-ad2100926eda'},
#  {'FacilityId': 'FA0010016',
#   'FacilityName': 'AFC SUSHI @ WALMART #3652',
#   'Address': '755 RIVERPOINT DR ',
#   'CityStateZip': 'WEST SACRAMENTO CA 95691 ',
#   'LastScore': 100.0,
#   'attachmentId': 'feec422f-cc1d-42ee-b7cb-adfe008d791a'},
#  {'FacilityId': 'FA0018619',
#   'FacilityName': 'AFC TIK TOK WOK @ SAFEWAY #1205',
#   'Address': '1451 W COVELL BLVD ',
#   'CityStateZip': 'DAVIS CA 95616 ',
#   'LastScore': 100.0,
#   'attachmentId': 'b6dc986d-cabc-4a10-ae18-ae1b00debf6b'},
#  {'FacilityId': 'FA0012949',
#   'FacilityName': 'AFRIDI FOOD COMPANY',
#   'Address': '1250 CHURCHILL DOWNS AVE D STE ',
#   'CityStateZip': 'WOODLAND CA 95776 ',
#   'LastScore': 100.0,
#   'attachmentId': 'e6c8ecab-92be-4109-a307-ade1010bc52a'},
#  {'FacilityId': 'FA0001050',
#   'FacilityName': 'AGGIE LIQUOR',
#   'Address': '507 L ST ',
#   'CityStateZip': 'DAVIS CA 95616 ',
#   'LastScore': 100.0,
#   'attachmentId': '3dd7fd23-3214-4051-b67e-ad7f01039b0b'},
#  {'FacilityId': 'FA0021027',
#   'FacilityName': 'AGTECH INNOVATION ALLIANCE',
#   'Address': '1100 MAIN ST 300 STE ',
#   'CityStateZip': 'WOODLAND CA 95695 ',
#   'LastScore': 100.0,
#   'attachmentId': 'f3a386ca-7eb8-43ff-8c66-ad4300f8f912'},
#  {'FacilityId': 'FA0005895',
#   'FacilityName': 'AISLE 1 #2576',
#   'Address': '1813 E GIBSON RD ',
#   'CityStateZip': 'WOODLAND CA 95776 ',
#   'LastScore': 100.0,
#   'attachmentId': '32430bf5-bb48-46c1-bc3f-ac92010ef2b2'},
#  {'FacilityId': 'FA0017313',
#   'FacilityName': 'AJ HUNDAL MART',
#   'Address': '2434 W CAPITOL AVE ',
#   'CityStateZip': 'WEST SACRAMENTO CA 95691 ',
#   'LastScore': 100.0,
#   'attachmentId': 'f5d5febb-cb42-4ec3-b7d5-adb900939a9b'},
#  {'FacilityId': 'FA0020303',
#   'FacilityName': 'AKIRA COFFEE & TEA',
#   'Address': '620 W COVELL BLVD A STE ',
#   'CityStateZip': 'DAVIS CA 95616 ',
#   'LastScore': 100.0,
#   'attachmentId': 'edf866ab-e17d-4d44-9d81-ae1c01058853'},
#  {'FacilityId': 'FA0006503',
#   'FacilityName': "AL & TOMI'S SHAVED ICE",
#   'Address': '8334 OLIVE SCHOOL RD ',
#   'CityStateZip': 'WINTERS CA 95694 ',
#   'LastScore': 100.0,
#   'attachmentId': '737d9d4a-3668-470d-a227-aa3c00f64043'},
#  {'FacilityId': 'FA0009941',
#   'FacilityName': 'ALDERSON CONVALESCENT - FOOD',
#   'Address': '124 WALNUT ST ',
#   'CityStateZip': 'WOODLAND CA 95695 ',
#   'LastScore': 100.0,
#   'attachmentId': 'de0878e6-0f22-4af9-bba7-ade800828c81'},
#  {'FacilityId': 'FA0001973',
#   'FacilityName': 'ALI BABA RESTAURANT',
#   'Address': '220 3RD ST ',
#   'CityStateZip': 'DAVIS CA 95616 ',
#   'LastScore': 100.0,
#   'attachmentId': '43e9d9ea-f28d-45e7-963e-ace901277735'},
#  {'FacilityId': 'FA0018627',
#   'FacilityName': 'ALKA PURE WATER',
#   'Address': '1620 W CAPITOL AVE ',
#   'CityStateZip': 'WEST SACRAMENTO CA 95691 ',
#   'LastScore': 100.0,
#   'attachmentId': 'c3e611eb-02f3-4736-b35f-adf1008c641e'},
#  {'FacilityId': 'FA0015993',
#   'FacilityName': 'ALL SEASONS ALL REASONS CATERING',
#   'Address': '2135 DALE AVE ',
#   'CityStateZip': 'SACRAMENTO CA 95815 ',
#   'LastScore': 100.0,
#   'attachmentId': '8a9a0dd1-8df6-4b4e-ab8e-adf90112df27'},
#  {'FacilityId': 'FA0019796',
#   'FacilityName': 'ALOHA POKEE & RAMEN',
#   'Address': '2055 TOWN CENTER PLZ 110 STE ',
#   'CityStateZip': 'WEST SACRAMENTO CA 95691 ',
#   'LastScore': 100.0,
#   'attachmentId': '8616befe-35cd-4465-8dd0-ad8600fb2082'},
#  {'FacilityId': 'FA0002033',
#   'FacilityName': 'ALYCE NORMAN SCHOOL',
#   'Address': '1200 ANNA ST ',
#   'CityStateZip': 'WEST SACRAMENTO CA 95605 ',
#   'LastScore': 100.0,
#   'attachmentId': '69a7e506-66e7-476b-a8cf-adc60088d28c'},
#  {'FacilityId': 'FA0002270',
#   'FacilityName': 'AM/PM MINI MARKET #5731- FOOD',
#   'Address': '805 REED AVE ',
#   'CityStateZip': 'WEST SACRAMENTO CA 95605 ',
#   'LastScore': 100.0,
#   'attachmentId': '926fecc8-5eb7-4597-a788-ae2800afd774'},
#  {'FacilityId': 'FA0020636',
#   'FacilityName': 'AMALUNA - PUBLIC CONCESSIONS',
#   'Address': "CIRQUE DU SOLEIL'S AMALUNA ",
#   'CityStateZip': 'WEST SACRAMENTO CA 95691 ',
#   'LastScore': 100.0,
#   'attachmentId': '80ec2fe7-47a7-4d1d-b9bb-ab5600a2edee'},
#  {'FacilityId': 'FA0020635',
#   'FacilityName': 'AMALUNA - STAFF KITCHEN',
#   'Address': "CIRQUE DU SOLEIL'S AMALUNA ",
#   'CityStateZip': 'WEST SACRAMENTO CA 95691 ',
#   'LastScore': 100.0,
#   'attachmentId': 'cf567238-9439-4a0f-b40a-ab5700d4d7d1'},
#  {'FacilityId': 'FA0020634',
#   'FacilityName': 'AMALUNA - VIP CATERING',
#   'Address': "CIRQUE DU SOLEIL'S AMALUNA ",
#   'CityStateZip': 'WEST SACRAMENTO CA 95691 ',
#   'LastScore': 100.0,
#   'attachmentId': 'd8d89f80-59c0-4114-ab7f-ab5700d58574'},
#  {'FacilityId': 'FA0020421',
#   'FacilityName': 'AMERICAN RIVER PROVISIONS',
#   'Address': 'YOLO COUNTY ',
#   'CityStateZip': 'WITH IN YOLO COUNTY CA 95695 ',
#   'LastScore': 100.0,
#   'attachmentId': '4b2f62eb-7166-4010-8fb4-aa9800e6a54d'},
#  {'FacilityId': 'FA0020398',
#   'FacilityName': 'AMY LOVES MUSTARD',
#   'Address': '2407 VAN GOGH ST ',
#   'CityStateZip': 'DAVIS CA 95618 ',
#   'LastScore': 100.0,
#   'attachmentId': '5a9838b3-59a5-47f6-a12e-ad2b00fa81fc'},
#  {'FacilityId': 'FA0012414',
#   'FacilityName': 'ANDERSON FAMILY CATERING BBQ',
#   'Address': '1286 CALLEN ST ',
#   'CityStateZip': 'VACAVILLE CA 95687 ',
#   'LastScore': 100.0,
#   'attachmentId': '18583f0a-1b68-44fd-bbdd-ad160107bfa6'},
#  {'FacilityId': 'FA0009436',
#   'FacilityName': 'ANDERSON GAS & MINI MART - FOOD',
#   'Address': '1935 ANDERSON RD ',
#   'CityStateZip': 'DAVIS CA 95616 ',
#   'LastScore': 100.0,
#   'attachmentId': '3ff4f0af-ef6d-48a6-9ef7-ad7f01002422'},
#  {'FacilityId': 'FA0002159',
#   'FacilityName': 'ANDERSON ROAD SHELL - FOOD',
#   'Address': '1944 ANDERSON RD ',
#   'CityStateZip': 'DAVIS CA 95616 ',
#   'LastScore': 100.0,
#   'attachmentId': None},
#  {'FacilityId': 'FA0002192',
#   'FacilityName': "ANDY'S ARCO - FOOD",
#   'Address': '313 W MAIN ST ',
#   'CityStateZip': 'WOODLAND CA 95695 ',
#   'LastScore': 100.0,
#   'attachmentId': 'f034bfe7-0f92-4b09-a543-adc1010b6ced'},
#  {'FacilityId': 'FA0020071',
#   'FacilityName': "ANN'S GLUTEN FREE GOODIES",
#   'Address': '1391 PARKVIEW DR ',
#   'CityStateZip': 'WOODLAND CA 95776 ',
#   'LastScore': 100.0,
#   'attachmentId': '53cd6abc-b4cd-445c-9936-acd400da45a2'},
#  {'FacilityId': 'FA0020747',
#   'FacilityName': 'ANTOJITOS JAIMITO #4TB1720',
#   'Address': '117 W MAIN ST ',
#   'CityStateZip': 'WOODLAND CA 95695 ',
#   'LastScore': 100.0,
#   'attachmentId': '5cd8c58c-f3b9-4ded-b094-adc10106d8bf'},
#  {'FacilityId': 'FA0020438',
#   'FacilityName': 'APNA BAZAAR',
#   'Address': '2 W COURT ST C STE ',
#   'CityStateZip': 'WOODLAND CA 95696 ',
#   'LastScore': 100.0,
#   'attachmentId': '4fdd227a-0b70-464f-b502-adac0115e934'},
#  {'FacilityId': 'FA0005596',
#   'FacilityName': "APPLEBEE'S - WOODLAND",
#   'Address': '1790 E MAIN ST ',
#   'CityStateZip': 'WOODLAND CA 95776 ',
#   'LastScore': 100.0,
#   'attachmentId': 'df19e47f-8a5f-4d65-a87a-adb30113bc70'},
#  {'FacilityId': 'FA0021060',
#   'FacilityName': 'ARATA SUSHI',
#   'Address': '1900 ANDERSON RD ',
#   'CityStateZip': 'DAVIS CA 95616 ',
#   'LastScore': 100.0,
#   'attachmentId': 'dda81dec-63a3-4d8d-a208-ad830081a84f'},
#  {'FacilityId': 'FA0020757',
#   'FacilityName': "ARBY'S #8806",
#   'Address': '85 W COURT ST ',
#   'CityStateZip': 'WOODLAND CA 95695 ',
#   'LastScore': 100.0,
#   'attachmentId': 'e549c6f1-1067-43d7-b14b-ae1a00e41f6a'},
#  {'FacilityId': 'FA0016070',
#   'FacilityName': 'ARCO AMPM GAS STATION',
#   'Address': '4480 CHILES RD ',
#   'CityStateZip': 'DAVIS CA 95618 ',
#   'LastScore': 100.0,
#   'attachmentId': 'f674e5cd-c0b5-4e46-b7df-ac21010466d0'},
#  {'FacilityId': 'FA0020258',
#   'FacilityName': 'ARMADILLO MUSIC INC.',
#   'Address': '207 F ST ',
#   'CityStateZip': 'DAVIS CA 95618 ',
#   'LastScore': 100.0,
#   'attachmentId': '46081833-bb64-42ee-bcb0-ad250107890a'},
#  {'FacilityId': 'FA0001394',
#   'FacilityName': "ARTEAGA'S SUPERMARKET INC",
#   'Address': '940 SACRAMENTO AVE ',
#   'CityStateZip': 'WEST SACRAMENTO CA 95605 ',
#   'LastScore': 100.0,
#   'attachmentId': '5d6be7ea-3b0c-4959-af19-adbb01044ce1'},
#  {'FacilityId': 'FA0020819',
#   'FacilityName': "AUNTIE YASY'S GLUTEN-FREE GOODIES & MEAL DELIVERY LLC",
#   'Address': '40162 BEST RANCH RD ',
#   'CityStateZip': 'WOODLAND CA 95776 ',
#   'LastScore': 100.0,
#   'attachmentId': 'ef5978a9-c33e-4d48-a350-ac7200d74432'},
#  {'FacilityId': 'FA0001628',
#   'FacilityName': 'AY! JALISCO TAQUERIA #1',
#   'Address': '966 SACRAMENTO Ave ',
#   'CityStateZip': 'WEST SACRAMENTO CA 95691 ',
#   'LastScore': 100.0,
#   'attachmentId': '4fa45198-aeea-48b1-a43a-adce0102c90e'}]

# %%
result = get_health_info("In-N-Out")

# %%
result
# Out:
# [{'FacilityId': 'FA0003293',
#   'FacilityName': 'IN-N-OUT BURGER #127',
#   'Address': '1020 OLIVE DR ',
#   'CityStateZip': 'DAVIS CA 95616 ',
#   'LastScore': 100.0,
#   'attachmentId': '24bf15d9-8778-415d-a098-ae0700fb9057'},
#  {'FacilityId': 'FA0011197',
#   'FacilityName': 'IN-N-OUT BURGER #231',
#   'Address': '2011 BRONZE STAR DR ',
#   'CityStateZip': 'WOODLAND CA 95776 ',
#   'LastScore': 100.0,
#   'attachmentId': None},
#  {'FacilityId': 'FA0003160',
#   'FacilityName': 'IN-N-OUT BURGERS #225',
#   'Address': '780 IKEA CT ',
#   'CityStateZip': 'WEST SACRAMENTO CA 95691 ',
#   'LastScore': 100.0,
#   'attachmentId': '641e66ee-2819-4c1a-a6f1-adbf0083baca'}]

# %%
result = get_health_info("Mikuni")
result
# Out:
# [{'FacilityId': 'FA0020204',
#   'FacilityName': 'MIKUNI JAPANESE RESTAURANT & SUSHI BAR',
#   'Address': '500 1ST ST 19 STE ',
#   'CityStateZip': 'DAVIS CA 95616 ',
#   'LastScore': 100.0,
#   'attachmentId': '02a6642a-08c4-483e-b200-ace501170842'}]

# %%
result_pd = pd.DataFrame(result)

# %%
result_pd
# Out:
#   FacilityId           FacilityName               Address  \
# 0  FA0003293   IN-N-OUT BURGER #127        1020 OLIVE DR
# 1  FA0011197   IN-N-OUT BURGER #231  2011 BRONZE STAR DR
# 2  FA0003160  IN-N-OUT BURGERS #225          780 IKEA CT
#
#                 CityStateZip  LastScore                          attachmentId
# 0            DAVIS CA 95616       100.0  24bf15d9-8778-415d-a098-ae0700fb9057
# 1         WOODLAND CA 95776       100.0                                  None
# 2  WEST SACRAMENTO CA 95691       100.0  641e66ee-2819-4c1a-a6f1-adbf0083baca

# %%
index = ["In-N-out", "ali baba", "crepeville"]
